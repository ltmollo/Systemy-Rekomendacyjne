# %% [markdown]
# # Laboratorium 1 - analiza koszykowa
#
# ## Przygotowanie
#
#  * pobierz i wypakuj dataset: https://kaggle.com/datasets/rashikrahmanpritom/groceries-dataset-for-market-basket-analysismba?resource=download&select=basket.csv
#    * alternatywnie, pobierz plik `basket.csv` z Teamsów
#  * [opcjonalnie] Utwórz wirtualne środowisko
#  `python3 -m venv ./recsyslab1`
#  * zainstaluj potrzebne biblioteki:
#  `pip install more-itertools`

# %% [markdown]
# ## Część 1. - przygotowanie danych

# %%
# importujemy wszystkie potrzebne pakiety
from more_itertools import powerset

# %%
# definiujemy stale

PATH = './basket.csv'
EPSILON = 0.001
K = 4

# %%
# wczytujemy dane o koszykach

def read_baskets(path: str) -> list[tuple[str]]:
    with open(path) as f:
        raw = f.read()
    baskets = [set([y.lower() for y in x.split(',') if y]) for x in raw.split('\n')[1:] if x]
    return baskets

def unique_products(baskets: list[tuple[str]]) -> list[str]:
    products = set()
    for basket in baskets:
        products.update(basket)
    return sorted(list(products))

baskets = read_baskets(PATH)
products = unique_products(baskets)

# %% [markdown]
# ## Część 2. - obliczanie wskaźników

# %%
# obliczamy strukture danych (np. slownik albo graf) przechowujaca wszystkie interesujace wartosci `support`

def get_basket_name(basket: tuple[str]):
    name = ', '.join(sorted(list(set(basket))))
    return name

def calculate_ratio(curr_basket: set[str], baskets: list[tuple[str]]):
    occurances = 0
    n = len(baskets)

    for basket in baskets:
        if curr_basket.issubset(basket):
            occurances += 1
     
    return occurances/n

def get_supports(baskets: list[tuple[str]], all_products: list[str], epsilon: float):
    supports = {}
     
    for basket in baskets:
        basket_set = set(basket)

        for possible_basket in powerset(basket_set):
            if len(possible_basket) == 0: continue
            
            possible_basket_set = set(possible_basket)

            possible_basket_key = get_basket_name(possible_basket_set)
            if possible_basket_key in supports:
                continue
              
            ratio = calculate_ratio(possible_basket_set, baskets)
            if ratio > epsilon:
                supports[possible_basket_key] = ratio
                
    return supports



# def get_supports(baskets: list[tuple[str]], all_products: list[str], epsilon: float):
#     product_subsets = []
#     for subset in powerset(all_products):
#         if len(list(subset)) == 0:
#             continue
#         if len(list(subset)) > K:
#             break
#         product_subsets.append(list(subset))

    
#     supports = {}
    
#     for product_subset in product_subsets:
#         contains = 0
#         for basket in baskets:
#             if product_subset.issubset(basket):
#                 contains += 1

#         name = get_basket_name(product_subset)
#         ratio = contains/len(baskets)
#         if ratio > epsilon:
#             supports[name] = contains/len(baskets)

#     return supports
       
supports = get_supports(baskets, products, EPSILON)
supports
# Out:
# {'pastry': 0.0517275947336764,
#  'salty snack': 0.018779656485998796,
#  'whole milk': 0.15792287642852368,
#  'pastry, whole milk': 0.006482657221145492,
#  'salty snack, whole milk': 0.0019381140145692708,
#  'sausage': 0.06034886052262247,
#  'yogurt': 0.08587850030074183,
#  'semi-finished bread': 0.009490075519615051,
#  'sausage, yogurt': 0.005747510525964045,
#  'sausage, whole milk': 0.008955423377664907,
#  'whole milk, yogurt': 0.011160863463209249,
#  'semi-finished bread, whole milk': 0.001670787943594199,
#  'sausage, whole milk, yogurt': 0.0014702933903628951,
#  'soda': 0.09710619528169484,
#  'pickled vegetables': 0.008955423377664907,
#  'misc. beverages': 0.01577223818752924,
#  'canned beer': 0.04691572545612511,
#  'hygiene articles': 0.013700461137472432,
#  'rolls/buns': 0.11000467820624206,
#  'rolls/buns, sausage': 0.005346521419501437,
#  'rolls/buns, whole milk': 0.013967787208447505,
#  'rolls/buns, sausage, whole milk': 0.0011361358016440553,
#  'soda, whole milk': 0.011628684087415625,
#  'whipped/sour cream': 0.043707812604424245,
#  'frankfurter': 0.037759807525228894,
#  'soda, whipped/sour cream': 0.003408407404932166,
#  'frankfurter, soda': 0.0030742498162133263,
#  'frankfurter, whipped/sour cream': 0.0014702933903628951,
#  'curd': 0.03368308494285905,
#  'curd, frankfurter': 0.0013366303548753592,
#  'white bread': 0.023992514870012697,
#  'beef': 0.03395041101383412,
#  'butter': 0.03522020985096572,
#  'butter, whole milk': 0.004678206242063757,
#  'frozen vegetables': 0.028002405934638777,
#  'other vegetables': 0.12210118291786407,
#  'frozen vegetables, other vegetables': 0.003141081333957094,
#  'sugar': 0.01771035220209851,
#  'tropical fruit': 0.0677671589921807,
#  'sugar, tropical fruit': 0.0010024727661565194,
#  'butter milk': 0.017576689166610975,
#  'specialty chocolate': 0.015972732740760543,
#  'frozen meals': 0.016774710953685757,
#  'dental care': 0.002205440085544343,
#  'detergent': 0.008621265788946068,
#  'root vegetables': 0.06957160997126245,
#  'cling film/bags': 0.004945532313038829,
#  'dish cleaner': 0.004878700795295061,
#  'frozen fish': 0.006816814809864332,
#  'pip fruit': 0.049054334023925686,
#  'tropical fruit, whole milk': 0.008220276682483459,
#  'pip fruit, whole milk': 0.006616320256633028,
#  'pip fruit, tropical fruit': 0.0020717770500568067,
#  'pastry, root vegetables': 0.0028737552629820224,
#  'root vegetables, whole milk': 0.00755196150504578,
#  'chocolate': 0.02359152576355009,
#  'red/blush wine': 0.01049254828577157,
#  'chocolate, rolls/buns': 0.002806923745238254,
#  'red/blush wine, rolls/buns': 0.0013366303548753592,
#  'shopping bags': 0.04758404063356279,
#  'other vegetables, shopping bags': 0.004945532313038829,
#  'packaged fruit/vegetables': 0.00848760275345853,
#  'chocolate, whole milk': 0.0029405867807257902,
#  'packaged fruit/vegetables, rolls/buns': 0.0012029673193878234,
#  'hygiene articles, other vegetables': 0.001403461872619127,
#  'margarine': 0.03221279155249616,
#  'margarine, whipped/sour cream': 0.0011361358016440553,
#  'bottled water': 0.06068301811134131,
#  'softener': 0.0027400922274944863,
#  'bottled water, rolls/buns': 0.004678206242063757,
#  'rice': 0.0032747443694446303,
#  'skin care': 0.0013366303548753592,
#  'flour': 0.009757401590590123,
#  'bottled beer': 0.04531176903027468,
#  'chicken': 0.027868742899151238,
#  'bottled beer, chocolate': 0.0010024727661565194,
#  'flour, whole milk': 0.0013366303548753592,
#  'bottled beer, whole milk': 0.007150972398583172,
#  'chicken, whole milk': 0.003408407404932166,
#  'frankfurter, whole milk': 0.005279689901757669,
#  'bottled beer, chicken': 0.0010024727661565194,
#  'bottled beer, rolls/buns': 0.004009891064626078,
#  'bottled beer, frankfurter': 0.001670787943594199,
#  'chicken, rolls/buns': 0.0028737552629820224,
#  'frankfurter, rolls/buns': 0.0036757334759072377,
#  'dessert': 0.02359152576355009,
#  'hamburger meat': 0.021853906302212123,
#  'liquor (appetizer)': 0.004477711688832453,
#  'liver loaf': 0.003341575887188398,
#  'domestic eggs': 0.037091492347791216,
#  'photo/film': 0.005279689901757669,
#  'white wine': 0.011695515605159393,
#  'domestic eggs, soda': 0.0025395976742631824,
#  'soda, yogurt': 0.005814342043707813,
#  'root vegetables, soda': 0.005279689901757669,
#  'soda, tropical fruit': 0.005413352937245205,
#  'domestic eggs, yogurt': 0.0020717770500568067,
#  'domestic eggs, root vegetables': 0.002004945532313039,
#  'domestic eggs, tropical fruit': 0.002138608567800575,
#  'root vegetables, yogurt': 0.00427721713560115,
#  'tropical fruit, yogurt': 0.005212858384013901,
#  'root vegetables, tropical fruit': 0.0036757334759072377,
#  'canned fish': 0.007685624540533315,
#  'cocoa drinks': 0.0010693042839002875,
#  'newspapers': 0.038895943326872955,
#  'herbs': 0.010559379803515338,
#  'newspapers, yogurt': 0.0028737552629820224,
#  'herbs, yogurt': 0.0011361358016440553,
#  'ketchup': 0.002138608567800575,
#  'coffee': 0.03161130789280225,
#  'uht-milk': 0.021386085678005748,
#  'coffee, pip fruit': 0.0010693042839002875,
#  'specialty bar': 0.013967787208447505,
#  'bottled water, frankfurter': 0.002205440085544343,
#  'sliced cheese': 0.014034618726191272,
#  'kitchen towels': 0.002004945532313039,
#  'candles': 0.004410880171088686,
#  'pip fruit, rolls/buns': 0.004945532313038829,
#  'curd cheese': 0.0030742498162133263,
#  'citrus fruit': 0.05313105660629553,
#  'candy': 0.014368776314910112,
#  'bottled water, citrus fruit': 0.0026064291920069507,
#  'citrus fruit, rolls/buns': 0.004678206242063757,
#  'candy, citrus fruit': 0.0010024727661565194,
#  'candy, rolls/buns': 0.0014702933903628951,
#  'grapes': 0.01443560783265388,
#  'grapes, whole milk': 0.0019381140145692708,
#  'grapes, other vegetables': 0.001603956425850431,
#  'herbs, whole milk': 0.0011361358016440553,
#  'other vegetables, whole milk': 0.014836596939116486,
#  'frankfurter, yogurt': 0.0025395976742631824,
#  'frankfurter, other vegetables': 0.005146026866270133,
#  'other vegetables, yogurt': 0.008086613646995923,
#  'other vegetables, whole milk, yogurt': 0.0011361358016440553,
#  'brown bread': 0.03762614448974136,
#  'processed cheese': 0.01015839069705273,
#  'processed cheese, whole milk': 0.0014702933903628951,
#  'onions': 0.02024994987636169,
#  'onions, rolls/buns': 0.0017376194613379669,
#  'onions, root vegetables': 0.0013366303548753592,
#  'onions, tropical fruit': 0.0012029673193878234,
#  'rolls/buns, shopping bags': 0.004745037759807526,
#  'root vegetables, shopping bags': 0.003341575887188398,
#  'shopping bags, tropical fruit': 0.0027400922274944863,
#  'rolls/buns, root vegetables': 0.005747510525964045,
#  'rolls/buns, tropical fruit': 0.006081668114682885,
#  'hard cheese': 0.01470293390362895,
#  'napkins': 0.022121232373187194,
#  'candy, whole milk': 0.002138608567800575,
#  'frozen vegetables, tropical fruit': 0.0010693042839002875,
#  'mustard': 0.006148499632426653,
#  'mayonnaise': 0.005012363830782597,
#  'frozen meals, whole milk': 0.0019381140145692708,
#  'meat': 0.016841542471429525,
#  'roll products ': 0.005480184454988973,
#  'domestic eggs, white bread': 0.0010024727661565194,
#  'bottled beer, sausage': 0.003341575887188398,
#  'bottled beer, yogurt': 0.003408407404932166,
#  'cookware': 0.0011361358016440553,
#  'fruit/vegetable juice': 0.03401724253157789,
#  'fruit/vegetable juice, rolls/buns': 0.003742564993651006,
#  'citrus fruit, whole milk': 0.007150972398583172,
#  'soft cheese': 0.010024727661565194,
#  'oil': 0.014903428456860256,
#  'frankfurter, pip fruit': 0.001804450979081735,
#  'oil, rolls/buns': 0.0013366303548753592,
#  'other vegetables, root vegetables': 0.005279689901757669,
#  'beef, yogurt': 0.002205440085544343,
#  'pet care': 0.005680679008220277,
#  'other vegetables, rolls/buns': 0.010559379803515338,
#  'dessert, soda': 0.0014702933903628951,
#  'shopping bags, soda': 0.004410880171088686,
#  'dessert, shopping bags': 0.0012029673193878234,
#  'long life bakery product': 0.017910846755329814,
#  'beverages': 0.016574216400454454,
#  'berries': 0.021787074784468355,
#  'cake bar': 0.006148499632426653,
#  'butter milk, root vegetables': 0.0010024727661565194,
#  'frozen meals, yogurt': 0.0013366303548753592,
#  'butter, yogurt': 0.002205440085544343,
#  'butter, newspapers': 0.001403461872619127,
#  'canned beer, shopping bags': 0.001871282496825503,
#  'spices': 0.0026732607097507185,
#  'canned beer, rolls/buns': 0.004210385617857381,
#  'baking powder': 0.008086613646995923,
#  'liquor': 0.0068836463276081,
#  'curd, tropical fruit': 0.001871282496825503,
#  'curd, yogurt': 0.0022722716032881106,
#  'whipped/sour cream, whole milk': 0.004611374724319989,
#  'fruit/vegetable juice, sausage': 0.001804450979081735,
#  'male cosmetics': 0.0024727661565194146,
#  'sausage, whipped/sour cream': 0.002138608567800575,
#  'rolls/buns, whipped/sour cream': 0.0029405867807257902,
#  'root vegetables, whipped/sour cream': 0.0024727661565194146,
#  'white bread, yogurt': 0.0010693042839002875,
#  'berries, yogurt': 0.001403461872619127,
#  'fish': 0.0019381140145692708,
#  'other vegetables, tropical fruit': 0.006282162667914188,
#  'coffee, shopping bags': 0.001403461872619127,
#  'ham': 0.0171088685424046,
#  'cream cheese ': 0.023658357281293858,
#  'dessert, sausage': 0.0014702933903628951,
#  'dessert, rolls/buns': 0.002004945532313039,
#  'citrus fruit, yogurt': 0.004611374724319989,
#  'butter, fruit/vegetable juice': 0.001403461872619127,
#  'canned beer, whipped/sour cream': 0.0015371249081066632,
#  'canned beer, root vegetables': 0.0020717770500568067,
#  'salt': 0.005948005079195348,
#  'pork': 0.037091492347791216,
#  'bottled water, onions': 0.0010024727661565194,
#  'butter, soda': 0.003141081333957094,
#  'flower (seeds)': 0.004611374724319989,
#  'ice cream': 0.015170754527835327,
#  'pot plants': 0.007819287576020852,
#  'berries, other vegetables': 0.0026732607097507185,
#  'newspapers, whipped/sour cream': 0.0015371249081066632,
#  'white bread, whole milk': 0.003141081333957094,
#  'pastry, shopping bags': 0.0013366303548753592,
#  'shopping bags, whole milk': 0.006348994185657956,
#  'soda, white bread': 0.0015371249081066632,
#  'berries, soda': 0.0014702933903628951,
#  'cream cheese , soda': 0.0014702933903628951,
#  'other vegetables, soda': 0.009690570072846355,
#  'other vegetables, white bread': 0.0026064291920069507,
#  'cream cheese , other vegetables': 0.002138608567800575,
#  'butter, other vegetables': 0.0028737552629820224,
#  'frankfurter, pastry': 0.0017376194613379669,
#  'snack products': 0.001804450979081735,
#  'rolls/buns, soda': 0.008086613646995923,
#  'waffles': 0.018512330415023724,
#  'cat food': 0.011829178640646929,
#  'pip fruit, yogurt': 0.00360890195816347,
#  'bottled water, domestic eggs': 0.002138608567800575,
#  'newspapers, tropical fruit': 0.001871282496825503,
#  'frozen vegetables, whole milk': 0.003809396511394774,
#  'rolls/buns, yogurt': 0.007819287576020852,
#  'rolls/buns, whole milk, yogurt': 0.0013366303548753592,
#  'frozen vegetables, sausage': 0.0020717770500568067,
#  'newspapers, whole milk': 0.005613847490476508,
#  'vinegar': 0.003408407404932166,
#  'rolls/buns, white bread': 0.002138608567800575,
#  'tropical fruit, white bread': 0.0010024727661565194,
#  'chewing gum': 0.012029673193878232,
#  'citrus fruit, shopping bags': 0.001804450979081735,
#  'canned beer, frankfurter': 0.0013366303548753592,
#  'canned beer, yogurt': 0.0038762280291385416,
#  'pip fruit, whipped/sour cream': 0.001670787943594199,
#  'pork, sausage': 0.0015371249081066632,
#  'butter, sausage': 0.0019381140145692708,
#  'fruit/vegetable juice, whole milk': 0.004410880171088686,
#  'pork, whole milk': 0.005012363830782597,
#  'other vegetables, specialty chocolate': 0.001670787943594199,
#  'instant food products': 0.004009891064626078,
#  'butter, whipped/sour cream': 0.0011361358016440553,
#  'rolls/buns, salty snack': 0.0019381140145692708,
#  'pasta': 0.008086613646995923,
#  'pasta, whole milk': 0.0010693042839002875,
#  'root vegetables, white bread': 0.0012697988371315912,
#  'chicken, tropical fruit': 0.001403461872619127,
#  'brown bread, tropical fruit': 0.0014702933903628951,
#  'brown bread, whole milk': 0.004477711688832453,
#  'prosecco': 0.0012697988371315912,
#  'hamburger meat, yogurt': 0.001670787943594199,
#  'chocolate marshmallow': 0.004009891064626078,
#  'napkins, whole milk': 0.0024059346387756467,
#  'curd, root vegetables': 0.0014702933903628951,
#  'butter, root vegetables': 0.002004945532313039,
#  'bottled water, pork': 0.001403461872619127,
#  'pip fruit, soda': 0.00394305954688231,
#  'curd, soda': 0.002806923745238254,
#  'sweet spreads': 0.004544543206576221,
#  'condensed milk': 0.0065494887388892606,
#  'rolls/buns, soda, whole milk': 0.0010024727661565194,
#  'house keeping products': 0.003007418298469558,
#  'dishes': 0.009022254895408675,
#  'other vegetables, uht-milk': 0.002138608567800575,
#  'meat, whole milk': 0.002205440085544343,
#  'bottled beer, hamburger meat': 0.0010693042839002875,
#  'cream cheese , tropical fruit': 0.001403461872619127,
#  'other vegetables, rolls/buns, soda': 0.0011361358016440553,
#  'popcorn': 0.003207912851700862,
#  'female sanitary products': 0.0026732607097507185,
#  'hamburger meat, tropical fruit': 0.0013366303548753592,
#  'hamburger meat, other vegetables': 0.002205440085544343,
#  'grapes, root vegetables': 0.0010693042839002875,
#  'beef, shopping bags': 0.0012697988371315912,
#  'hamburger meat, soda': 0.001670787943594199,
#  'dog food': 0.004477711688832453,
#  'margarine, yogurt': 0.002138608567800575,
#  'butter milk, yogurt': 0.0012697988371315912,
#  'detergent, yogurt': 0.0010693042839002875,
#  'soft cheese, yogurt': 0.0012697988371315912,
#  'other vegetables, soft cheese': 0.0012029673193878234,
#  'pork, shopping bags': 0.0015371249081066632,
#  'pork, yogurt': 0.0030742498162133263,
#  'other vegetables, pork': 0.00394305954688231,
#  'shopping bags, yogurt': 0.003542070440419702,
#  'rolls/buns, waffles': 0.001603956425850431,
#  'sugar, whole milk': 0.0024727661565194146,
#  'hamburger meat, pastry': 0.0010024727661565194,
#  'fruit/vegetable juice, soda': 0.002138608567800575,
#  'citrus fruit, margarine': 0.0011361358016440553,
#  'frankfurter, margarine': 0.001603956425850431,
#  'citrus fruit, frankfurter': 0.0017376194613379669,
#  'bottled water, newspapers': 0.001804450979081735,
#  'bottled water, soda': 0.0048118692775512934,
#  'bottled water, yogurt': 0.003809396511394774,
#  'newspapers, soda': 0.0023391031210318785,
#  'ham, whole milk': 0.0027400922274944863,
#  'meat spreads': 0.0023391031210318785,
#  'other vegetables, pip fruit': 0.004945532313038829,
#  'sliced cheese, soda': 0.0011361358016440553,
#  'tropical fruit, uht-milk': 0.0015371249081066632,
#  'chicken, other vegetables': 0.002205440085544343,
#  'bottled water, sausage': 0.003141081333957094,
#  'salty snack, sausage': 0.0011361358016440553,
#  'spread cheese': 0.006683151774376796,
#  'bottled beer, soda': 0.0029405867807257902,
#  'bottled beer, fruit/vegetable juice': 0.001670787943594199,
#  'margarine, whole milk': 0.0040767225823698456,
#  'margarine, root vegetables': 0.0019381140145692708,
#  'margarine, tropical fruit': 0.0014702933903628951,
#  'sauces': 0.0029405867807257902,
#  'long life bakery product, tropical fruit': 0.0010693042839002875,
#  'long life bakery product, other vegetables': 0.0011361358016440553,
#  'long life bakery product, whole milk': 0.0024059346387756467,
#  'butter, shopping bags': 0.0013366303548753592,
#  'cream cheese , rolls/buns': 0.001871282496825503,
#  'rum': 0.002138608567800575,
#  'frankfurter, tropical fruit': 0.0013366303548753592,
#  'bottled beer, root vegetables': 0.0024727661565194146,
#  'chocolate, tropical fruit': 0.001403461872619127,
#  'coffee, rolls/buns': 0.0024059346387756467,
#  'coffee, tropical fruit': 0.0015371249081066632,
#  'pork, rolls/buns': 0.003408407404932166,
#  'bottled beer, tropical fruit': 0.0025395976742631824,
#  'fruit/vegetable juice, yogurt': 0.002205440085544343,
#  'ham, other vegetables': 0.001603956425850431,
#  'finished products': 0.00427721713560115,
#  'curd, pip fruit': 0.0013366303548753592,
#  'instant coffee': 0.00394305954688231,
#  'bottled water, fruit/vegetable juice': 0.0012029673193878234,
#  'citrus fruit, fruit/vegetable juice': 0.0013366303548753592,
#  'frankfurter, fruit/vegetable juice': 0.0011361358016440553,
#  'brown bread, sausage': 0.001804450979081735,
#  'bottled water, chicken': 0.0013366303548753592,
#  'bottled water, butter': 0.001804450979081735,
#  'butter, frankfurter': 0.001403461872619127,
#  'coffee, whole milk': 0.003809396511394774,
#  'artif. sweetener': 0.0019381140145692708,
#  'canned beer, soda': 0.003141081333957094,
#  'brown bread, white bread': 0.0010024727661565194,
#  'chicken, soda': 0.002138608567800575,
#  'coffee, frankfurter': 0.0014702933903628951,
#  'curd, rolls/buns': 0.0027400922274944863,
#  'napkins, rolls/buns': 0.0017376194613379669,
#  'frozen vegetables, root vegetables': 0.002138608567800575,
#  'specialty bar, yogurt': 0.0012029673193878234,
#  'other vegetables, pastry': 0.0036757334759072377,
#  'newspapers, pastry': 0.002004945532313039,
#  'newspapers, other vegetables': 0.0036757334759072377,
#  'frankfurter, newspapers': 0.0010693042839002875,
#  'beef, margarine': 0.001403461872619127,
#  'margarine, other vegetables': 0.003207912851700862,
#  'beef, other vegetables': 0.002806923745238254,
#  'bathroom cleaner': 0.0011361358016440553,
#  'soda, specialty chocolate': 0.001403461872619127,
#  'hamburger meat, whole milk': 0.0030742498162133263,
#  'citrus fruit, root vegetables': 0.002205440085544343,
#  'canned beer, margarine': 0.0012029673193878234,
#  'beef, soda': 0.001804450979081735,
#  'beef, curd': 0.0012697988371315912,
#  'beef, butter': 0.0011361358016440553,
#  'curd, other vegetables': 0.003542070440419702,
#  'beverages, sausage': 0.0015371249081066632,
#  'jam': 0.0022722716032881106,
#  'chocolate, sausage': 0.001403461872619127,
#  'pip fruit, sausage': 0.002138608567800575,
#  'chocolate, pip fruit': 0.0013366303548753592,
#  'hard cheese, whole milk': 0.001871282496825503,
#  'domestic eggs, other vegetables': 0.003542070440419702,
#  'meat, other vegetables': 0.002138608567800575,
#  'napkins, yogurt': 0.0017376194613379669,
#  'napkins, pastry': 0.0017376194613379669,
#  'pastry, yogurt': 0.00360890195816347,
#  'pastry, sausage': 0.003207912851700862,
#  'ice cream, whole milk': 0.0019381140145692708,
#  'soda, specialty bar': 0.0012697988371315912,
#  'frozen vegetables, soda': 0.002004945532313039,
#  'other vegetables, specialty bar': 0.001670787943594199,
#  'domestic eggs, sausage': 0.001804450979081735,
#  'bottled beer, domestic eggs': 0.001670787943594199,
#  'domestic eggs, rolls/buns': 0.003408407404932166,
#  'grapes, sausage': 0.0010693042839002875,
#  'grapes, rolls/buns': 0.0012029673193878234,
#  'bottled beer, bottled water': 0.0025395976742631824,
#  'bottled beer, other vegetables': 0.004678206242063757,
#  'waffles, whole milk': 0.0026064291920069507,
#  'root vegetables, sausage': 0.003341575887188398,
#  'sausage, tropical fruit': 0.0030742498162133263,
#  'misc. beverages, sausage': 0.0010693042839002875,
#  'misc. beverages, root vegetables': 0.0010024727661565194,
#  'domestic eggs, pork': 0.0012029673193878234,
#  'fruit/vegetable juice, pip fruit': 0.001403461872619127,
#  'curd, whipped/sour cream': 0.001670787943594199,
#  'shopping bags, whipped/sour cream': 0.0012029673193878234,
#  'curd, shopping bags': 0.0012697988371315912,
#  'curd, whole milk': 0.004143554100113613,
#  'bottled water, whipped/sour cream': 0.001804450979081735,
#  'cat food, rolls/buns': 0.0010693042839002875,
#  'hard cheese, yogurt': 0.0012697988371315912,
#  'specialty chocolate, whole milk': 0.0013366303548753592,
#  'canned beer, whole milk': 0.006014836596939116,
#  'specialty chocolate, tropical fruit': 0.0013366303548753592,
#  'canned beer, tropical fruit': 0.0025395976742631824,
#  'citrus fruit, tropical fruit': 0.0028737552629820224,
#  'citrus fruit, specialty chocolate': 0.001403461872619127,
#  'canned beer, citrus fruit': 0.0015371249081066632,
#  'bottled water, root vegetables': 0.0034752389226759338,
#  'bottled water, frozen vegetables': 0.0010693042839002875,
#  'brown bread, pip fruit': 0.001670787943594199,
#  'pudding powder': 0.0011361358016440553,
#  'grapes, soda': 0.001403461872619127,
#  'butter milk, soda': 0.001403461872619127,
#  'hygiene articles, soda': 0.0010693042839002875,
#  'sparkling wine': 0.0030742498162133263,
#  'other vegetables, whipped/sour cream': 0.004143554100113613,
#  'brown bread, yogurt': 0.0023391031210318785,
#  'chicken, pastry': 0.0012697988371315912,
#  'tea': 0.001804450979081735,
#  'bottled water, whole milk': 0.007150972398583172,
#  'bottled water, tropical fruit': 0.003542070440419702,
#  'specialty fat': 0.0019381140145692708,
#  'beef, newspapers': 0.001670787943594199,
#  'chicken, shopping bags': 0.0012697988371315912,
#  'pastry, whipped/sour cream': 0.0015371249081066632,
#  'canned beer, pastry': 0.001871282496825503,
#  'frozen potato products': 0.0048118692775512934,
#  'specialty cheese': 0.0048118692775512934,
#  'brown bread, shopping bags': 0.0012697988371315912,
#  'margarine, pip fruit': 0.0012697988371315912,
#  'pastry, pip fruit': 0.002205440085544343,
#  'citrus fruit, frozen vegetables': 0.001603956425850431,
#  'bottled water, chocolate': 0.001403461872619127,
#  'salty snack, soda': 0.001403461872619127,
#  'ham, yogurt': 0.0012697988371315912,
#  'margarine, pastry': 0.0013366303548753592,
#  'curd, margarine': 0.0010693042839002875,
#  'butter, margarine': 0.001403461872619127,
#  'curd, pastry': 0.001403461872619127,
#  'butter, pastry': 0.0015371249081066632,
#  'soda, uht-milk': 0.0012697988371315912,
#  'uht-milk, whole milk': 0.0025395976742631824,
#  'bottled water, sugar': 0.0014702933903628951,
#  'canned beer, curd': 0.0012029673193878234,
#  'sausage, shopping bags': 0.0019381140145692708,
#  'turkey': 0.005346521419501437,
#  'whipped/sour cream, yogurt': 0.0029405867807257902,
#  'napkins, other vegetables': 0.002138608567800575,
#  'canned vegetables': 0.005480184454988973,
#  'brown bread, soda': 0.0028737552629820224,
#  'zwieback': 0.004009891064626078,
#  'hard cheese, root vegetables': 0.0010024727661565194,
#  'hard cheese, other vegetables': 0.001670787943594199,
#  'cream cheese , root vegetables': 0.001603956425850431,
#  'newspapers, root vegetables': 0.0025395976742631824,
#  'beverages, rolls/buns': 0.0012029673193878234,
#  'newspapers, rolls/buns': 0.003007418298469558,
#  'bottled beer, frozen vegetables': 0.001403461872619127,
#  'canned beer, pip fruit': 0.001603956425850431,
#  'brown bread, citrus fruit': 0.0017376194613379669,
#  'pastry, tropical fruit': 0.002806923745238254,
#  'oil, yogurt': 0.0010693042839002875,
#  'frozen vegetables, rolls/buns': 0.0027400922274944863,
#  'pork, soda': 0.003007418298469558,
#  'margarine, rolls/buns': 0.003007418298469558,
#  'misc. beverages, whole milk': 0.001403461872619127,
#  'napkins, root vegetables': 0.0010693042839002875,
#  'pork, root vegetables': 0.0017376194613379669,
#  'citrus fruit, soda': 0.003742564993651006,
#  'margarine, shopping bags': 0.0010024727661565194,
#  'frankfurter, shopping bags': 0.0015371249081066632,
#  'margarine, soda': 0.0026064291920069507,
#  'bottled water, dessert': 0.0010693042839002875,
#  'dessert, root vegetables': 0.0010693042839002875,
#  'frankfurter, root vegetables': 0.002205440085544343,
#  'other vegetables, salty snack': 0.002205440085544343,
#  'other vegetables, semi-finished bread': 0.0010024727661565194,
#  'oil, other vegetables': 0.001804450979081735,
#  'brown bread, pastry': 0.002004945532313039,
#  'sausage, soda': 0.005948005079195348,
#  'butter milk, tropical fruit': 0.0010024727661565194,
#  'nut snack': 0.0014702933903628951,
#  'other vegetables, sugar': 0.0012697988371315912,
#  'citrus fruit, napkins': 0.001403461872619127,
#  'butter milk, rolls/buns': 0.0012697988371315912,
#  'brown bread, rolls/buns': 0.003341575887188398,
#  'brown bread, canned beer': 0.0024059346387756467,
#  'other vegetables, waffles': 0.0017376194613379669,
#  'soups': 0.003207912851700862,
#  'soda, sugar': 0.0012029673193878234,
#  'coffee, root vegetables': 0.002004945532313039,
#  'chicken, domestic eggs': 0.0010024727661565194,
#  'brown bread, other vegetables': 0.0030742498162133263,
#  'cereals': 0.002806923745238254,
#  'pip fruit, root vegetables': 0.0026732607097507185,
#  'frozen vegetables, pip fruit': 0.0013366303548753592,
#  'other vegetables, sliced cheese': 0.001403461872619127,
#  'candy, other vegetables': 0.0011361358016440553,
#  'bottled water, shopping bags': 0.002004945532313039,
#  'margarine, pork': 0.0013366303548753592,
#  'long life bakery product, soda': 0.0013366303548753592,
#  'sausage, white bread': 0.001403461872619127,
#  'sliced cheese, whole milk': 0.0014702933903628951,
#  'sausage, sliced cheese': 0.0011361358016440553,
#  'pork, tropical fruit': 0.0015371249081066632,
#  'chicken, yogurt': 0.001804450979081735,
#  'seasonal products': 0.007084140880839404,
#  'frozen vegetables, yogurt': 0.0020717770500568067,
#  'bottled water, uht-milk': 0.0010693042839002875,
#  'rolls/buns, uht-milk': 0.001804450979081735,
#  'long life bakery product, rolls/buns': 0.001670787943594199,
#  'berries, pip fruit': 0.0011361358016440553,
#  'fruit/vegetable juice, other vegetables': 0.0029405867807257902,
#  'berries, pastry': 0.0010693042839002875,
#  'frozen meals, soda': 0.0015371249081066632,
#  'ready soups': 0.0010024727661565194,
#  'chewing gum, whole milk': 0.001670787943594199,
#  'citrus fruit, sausage': 0.0012029673193878234,
#  'canned beer, sausage': 0.0024727661565194146,
#  'brandy': 0.0025395976742631824,
#  'napkins, tropical fruit': 0.0012697988371315912,
#  'cream cheese , whole milk': 0.0028737552629820224,
#  'butter, rolls/buns': 0.0028737552629820224,
#  'light bulbs': 0.0019381140145692708,
#  'beef, domestic eggs': 0.0011361358016440553,
#  'coffee, domestic eggs': 0.001403461872619127,
#  'beef, bottled beer': 0.0010693042839002875,
#  'bottled beer, newspapers': 0.0017376194613379669,
#  'canned beer, fruit/vegetable juice': 0.0015371249081066632,
#  'citrus fruit, newspapers': 0.0012029673193878234,
#  'beef, bottled water': 0.0013366303548753592,
#  'beef, citrus fruit': 0.001804450979081735,
#  'beef, whole milk': 0.004678206242063757,
#  'brown bread, root vegetables': 0.0013366303548753592,
#  'frankfurter, frozen vegetables': 0.0010693042839002875,
#  'cleaner': 0.0020717770500568067,
#  'chicken, pip fruit': 0.0010693042839002875,
#  'citrus fruit, whipped/sour cream': 0.0020717770500568067,
#  'hard cheese, rolls/buns': 0.001670787943594199,
#  'syrup': 0.001403461872619127,
#  'rolls/buns, soft cheese': 0.0010024727661565194,
#  'chocolate, yogurt': 0.001603956425850431,
#  'berries, bottled water': 0.0010693042839002875,
#  'white wine, whole milk': 0.0012697988371315912,
#  'ice cream, other vegetables': 0.0012697988371315912,
#  'citrus fruit, white bread': 0.0011361358016440553,
#  'oil, whole milk': 0.0019381140145692708,
#  'soft cheese, whole milk': 0.0012029673193878234,
#  'brown bread, butter': 0.0010024727661565194,
#  'other vegetables, sausage': 0.006014836596939116,
#  'dessert, other vegetables': 0.0020717770500568067,
#  'canned beer, other vegetables': 0.004009891064626078,
#  'cream cheese , sausage': 0.0012029673193878234,
#  'bottled beer, canned beer': 0.001871282496825503,
#  'bottled beer, brown bread': 0.0015371249081066632,
#  'bottled beer, butter': 0.001670787943594199,
#  'butter, canned beer': 0.0010024727661565194,
#  'canned fruit': 0.001403461872619127,
#  'citrus fruit, domestic eggs': 0.0012697988371315912,
#  'onions, other vegetables': 0.0015371249081066632,
#  'dessert, tropical fruit': 0.0010693042839002875,
#  'citrus fruit, other vegetables': 0.0048118692775512934,
#  'pastry, soda': 0.0040767225823698456,
#  'coffee, soda': 0.0024727661565194146,
#  'coffee, pastry': 0.001403461872619127,
#  'pip fruit, shopping bags': 0.001871282496825503,
#  'domestic eggs, newspapers': 0.0015371249081066632,
#  'beef, whipped/sour cream': 0.001403461872619127,
#  'root vegetables, sliced cheese': 0.0012029673193878234,
#  'misc. beverages, yogurt': 0.0012697988371315912,
#  'beverages, soda': 0.001871282496825503,
#  'pastry, rolls/buns': 0.00394305954688231,
#  'chicken, root vegetables': 0.0010024727661565194,
#  'bottled water, white bread': 0.0012697988371315912,
#  'bottled water, curd': 0.0019381140145692708,
#  'chewing gum, yogurt': 0.001403461872619127,
#  'other vegetables, soda, whole milk': 0.0011361358016440553,
#  'sausage, soda, whole milk': 0.0010693042839002875,
#  'other vegetables, rolls/buns, whole milk': 0.0012029673193878234,
#  'frozen meals, rolls/buns': 0.0014702933903628951,
#  'specialty bar, whole milk': 0.001670787943594199,
#  'rolls/buns, specialty bar': 0.0012029673193878234,
#  'salty snack, tropical fruit': 0.0010024727661565194,
#  'cat food, tropical fruit': 0.0010024727661565194,
#  'chicken, margarine': 0.0010024727661565194,
#  'brown bread, pork': 0.001670787943594199,
#  'beef, brown bread': 0.0015371249081066632,
#  'domestic eggs, fruit/vegetable juice': 0.0010693042839002875,
#  'bottled beer, citrus fruit': 0.001670787943594199,
#  'napkins, soda': 0.0015371249081066632,
#  'bottled water, pastry': 0.0028737552629820224,
#  'canned beer, chocolate': 0.0010693042839002875,
#  'rolls/buns, specialty chocolate': 0.0012697988371315912,
#  'canned beer, coffee': 0.0010024727661565194,
#  'butter, citrus fruit': 0.0019381140145692708,
#  'cooking chocolate': 0.0010024727661565194,
#  'detergent, whole milk': 0.001403461872619127,
#  'canned beer, salty snack': 0.0010024727661565194,
#  'butter milk, other vegetables': 0.0012697988371315912,
#  'bottled water, margarine': 0.001403461872619127,
#  'coffee, yogurt': 0.0020717770500568067,
#  'root vegetables, salty snack': 0.0010693042839002875,
#  'abrasive cleaner': 0.0014702933903628951,
#  'newspapers, pip fruit': 0.0012697988371315912,
#  'ham, soda': 0.0012029673193878234,
#  'ham, tropical fruit': 0.0011361358016440553,
#  'meat, soda': 0.0010024727661565194,
#  'frozen fish, whole milk': 0.0010693042839002875,
#  'frozen meals, sausage': 0.0012697988371315912,
#  'candy, soda': 0.0012697988371315912,
#  'berries, tropical fruit': 0.0012697988371315912,
#  'citrus fruit, coffee': 0.0013366303548753592,
#  'chewing gum, other vegetables': 0.0010693042839002875,
#  'pot plants, whole milk': 0.0010024727661565194,
#  'coffee, sausage': 0.0013366303548753592,
#  'frozen dessert': 0.006148499632426653,
#  'curd, sausage': 0.0029405867807257902,
#  'domestic eggs, whole milk': 0.005279689901757669,
#  'pickled vegetables, whole milk': 0.0010024727661565194,
#  'onions, whole milk': 0.0029405867807257902,
#  'organic sausage': 0.0014702933903628951,
#  'butter, tropical fruit': 0.0015371249081066632,
#  'root vegetables, waffles': 0.0013366303548753592,
#  'root vegetables, uht-milk': 0.0010024727661565194,
#  'citrus fruit, pip fruit': 0.0014702933903628951,
#  'chicken, curd': 0.0011361358016440553,
#  'citrus fruit, curd': 0.0011361358016440553,
#  'citrus fruit, pastry': 0.002138608567800575,
#  'citrus fruit, cream cheese ': 0.0010024727661565194,
#  'chicken, citrus fruit': 0.0012029673193878234,
#  'rolls/buns, seasonal products': 0.0010024727661565194,
#  'butter milk, whole milk': 0.001670787943594199,
#  'flower soil/fertilizer': 0.0010693042839002875,
#  'pastry, pork': 0.0015371249081066632,
#  'tidbits': 0.0014702933903628951,
#  'coffee, other vegetables': 0.0026064291920069507,
#  'domestic eggs, shopping bags': 0.0014702933903628951,
#  'butter milk, shopping bags': 0.0010024727661565194,
#  'dessert, yogurt': 0.0012029673193878234,
#  'dessert, whole milk': 0.0024059346387756467,
#  'meat, root vegetables': 0.0013366303548753592,
#  'bottled water, canned beer': 0.0014702933903628951,
#  'canned beer, frozen vegetables': 0.0013366303548753592,
#  'bottled water, other vegetables': 0.005480184454988973,
#  'beverages, whole milk': 0.0019381140145692708,
#  'hamburger meat, rolls/buns': 0.0019381140145692708,
#  'frozen meals, other vegetables': 0.002138608567800575,
#  'butter, pip fruit': 0.0011361358016440553,
#  'margarine, sausage': 0.001871282496825503,
#  'cat food, whole milk': 0.001670787943594199,
#  'frankfurter, sausage': 0.0014702933903628951,
#  'misc. beverages, other vegetables': 0.0012029673193878234,
#  'hard cheese, pip fruit': 0.0010693042839002875,
#  'canned beer, white bread': 0.0015371249081066632,
#  'fruit/vegetable juice, root vegetables': 0.001804450979081735,
#  'citrus fruit, pork': 0.0013366303548753592,
#  'bottled beer, curd': 0.0011361358016440553,
#  'canned beer, pork': 0.001670787943594199,
#  'bottled beer, shopping bags': 0.0014702933903628951,
#  'hygiene articles, rolls/buns': 0.0013366303548753592,
#  'chocolate, soda': 0.001670787943594199,
#  'chewing gum, soda': 0.0010024727661565194,
#  'beef, canned beer': 0.0010024727661565194,
#  'chicken, sausage': 0.0010693042839002875,
#  'fruit/vegetable juice, tropical fruit': 0.002138608567800575,
#  'processed cheese, rolls/buns': 0.0014702933903628951,
#  'brown bread, whipped/sour cream': 0.0010693042839002875,
#  'bottled beer, pastry': 0.0020717770500568067,
#  'oil, soda': 0.001804450979081735,
#  'beef, pastry': 0.0012029673193878234,
#  'beef, rolls/buns': 0.001603956425850431,
#  'beef, frankfurter': 0.0010024727661565194,
#  'chocolate, root vegetables': 0.0012029673193878234,
#  'detergent, rolls/buns': 0.0010024727661565194,
#  'meat, rolls/buns': 0.0013366303548753592,
#  'canned beer, newspapers': 0.001871282496825503,
#  'ice cream, soda': 0.0012029673193878234,
#  'onions, soda': 0.0014702933903628951,
#  'flour, tropical fruit': 0.0010693042839002875,
#  'beef, tropical fruit': 0.0011361358016440553,
#  'tropical fruit, whipped/sour cream': 0.0024727661565194146,
#  'bottled water, coffee': 0.0015371249081066632,
#  'fruit/vegetable juice, pastry': 0.0014702933903628951,
#  'brown bread, curd': 0.0012029673193878234,
#  'chocolate, other vegetables': 0.001871282496825503,
#  'canned beer, domestic eggs': 0.0012029673193878234,
#  'onions, whipped/sour cream': 0.0010693042839002875,
#  'ice cream, rolls/buns': 0.0017376194613379669,
#  'cream cheese , shopping bags': 0.0012029673193878234,
#  'newspapers, sausage': 0.001804450979081735,
#  'tropical fruit, waffles': 0.0011361358016440553,
#  'chicken, whipped/sour cream': 0.0012697988371315912,
#  'cream cheese , frankfurter': 0.0010024727661565194,
#  'hygiene articles, root vegetables': 0.0010024727661565194,
#  'newspapers, shopping bags': 0.001804450979081735,
#  'potato products': 0.0015371249081066632,
#  'salty snack, yogurt': 0.0015371249081066632,
#  'ham, rolls/buns': 0.0012697988371315912,
#  'domestic eggs, pastry': 0.0013366303548753592,
#  'hamburger meat, root vegetables': 0.0012697988371315912,
#  'hygiene articles, whole milk': 0.0017376194613379669,
#  'bottled water, brown bread': 0.0015371249081066632,
#  'waffles, yogurt': 0.0011361358016440553,
#  'beef, root vegetables': 0.001670787943594199,
#  'curd, pork': 0.0011361358016440553,
#  'berries, rolls/buns': 0.001670787943594199,
#  'bottled water, pip fruit': 0.002004945532313039,
#  'sausage, uht-milk': 0.0011361358016440553,
#  'uht-milk, yogurt': 0.0011361358016440553,
#  'bottled beer, pip fruit': 0.0015371249081066632,
#  'beef, fruit/vegetable juice': 0.0010693042839002875,
#  'bottled beer, whipped/sour cream': 0.0012029673193878234,
#  'brown bread, domestic eggs': 0.0012029673193878234,
#  'curd, dessert': 0.0010024727661565194,
#  'beef, frozen vegetables': 0.0012697988371315912,
#  'candy, yogurt': 0.0012029673193878234,
#  'nuts/prunes': 0.002205440085544343,
#  'brown bread, frankfurter': 0.0015371249081066632,
#  'onions, yogurt': 0.0012697988371315912,
#  'long life bakery product, yogurt': 0.0012029673193878234,
#  'fruit/vegetable juice, margarine': 0.0010024727661565194,
#  'processed cheese, root vegetables': 0.0010693042839002875,
#  'soap': 0.0013366303548753592,
#  'whipped/sour cream, white bread': 0.0010024727661565194,
#  'other vegetables, pot plants': 0.0010024727661565194,
#  'beverages, bottled water': 0.0010693042839002875,
#  'domestic eggs, frankfurter': 0.001403461872619127,
#  'berries, whole milk': 0.0022722716032881106,
#  'beverages, other vegetables': 0.0017376194613379669,
#  'pip fruit, pork': 0.001603956425850431,
#  'misc. beverages, rolls/buns': 0.0013366303548753592,
#  'long life bakery product, sausage': 0.0010693042839002875,
#  'cream cheese , yogurt': 0.001603956425850431,
#  'chocolate, citrus fruit': 0.0010693042839002875,
#  'other vegetables, red/blush wine': 0.0011361358016440553,
#  'bottled beer, margarine': 0.0010693042839002875,
#  'berries, root vegetables': 0.0010693042839002875,
#  'bottled beer, pork': 0.0010693042839002875,
#  'canned beer, chicken': 0.0011361358016440553}

# %%
# definiujemy funkcje obliczajace support, confidence i lift

def support(supports, products: tuple[str]) -> float:
    name = get_basket_name(products)
    if name in supports:
        return supports[name]
    
    return EPSILON

def confidence(supports, prior_products: tuple[str], following_products: tuple[str]) -> float:
    AuB = prior_products.union(following_products)
    supp_AuB = support(supports, AuB)
    supp_A = support(supports, prior_products)
    return supp_AuB/supp_A
    
def lift(supports, prior_products: tuple[str], following_products: tuple[str]) -> float:
    AuB = prior_products.union(following_products)
    supp_AuB = support(supports, AuB)
    supp_A = support(supports, prior_products)
    supp_B = support(supports, following_products)
    return supp_AuB/(supp_A * supp_B)

# %%
print(support(supports, {'whole milk', 'rolls/buns'}))
print(confidence(supports, {'whole milk', 'rolls/buns'}, {'yogurt'}))
print(lift(supports, {'whole milk', 'rolls/buns'}, {'yogurt'}))
# Out:
# 0.013967787208447505
# 0.09569377990430622
# 1.1142926293448512

# %% [markdown]
# ## Część 3. - generowanie rekomendacji

# %%
# wyznaczamy liste potencjalnych rekomendacji
# rekomendowane artykuly powinny miec lift > 1 i jak najwyzszy confidence

def generate_basic_candidates(basket: tuple[str], products: list[str], supports) -> list[tuple[str, tuple[str], float, float]]:
    # return [(item, subbasket, confidence, lift)]
    recomendations = []

    for sub_basket in powerset(basket):
        if len(sub_basket) == 0: continue
        sub_basket_set = set(sub_basket)

        for product in products:
            if product in basket:
                continue

            _lift = lift(supports, sub_basket_set, (product, ))
            if _lift > 1:

                _confidence = confidence(supports, sub_basket_set, (product, ))
                recomendations.append((product, sub_basket, _confidence, _lift))

    sorted_recomendations = sorted(recomendations, key=lambda x: x[2], reverse=True)
    return sorted_recomendations

# %%
# zaproponuj drugi, bardziej zaawansowany algorytm, np.:
# - jesli produkt X wystepuje w liscie kandydatow kilkukrotnie, oblicz srednia lub iloczyn confidence
# - posortuj kandydatow po iloczynie configence i lift

def generate_advanced_candidates(basket: tuple[str], products: list[str], supports) -> list[tuple[str, tuple[str], float, float]]:
   # return [(item, subbasket, confidence, lift)]
    recomendations = []
    confidences = {}

    for sub_basket in powerset(basket):
        if len(sub_basket) == 0: continue
        sub_basket_set = set(sub_basket)

        for product in products:
            if product in basket:
                continue

            _lift = lift(supports, sub_basket_set, (product, ))
            if _lift > 1:

                _confidence = confidence(supports, sub_basket_set, (product, ))
                if product in confidences:
                    _confidence *= confidences[product]
                    confidences[product] = _confidence
                else:
                    confidences[product] = _confidence
                                        
                recomendations.append((product, sub_basket, _confidence, _lift))

    sorted_recomendations = sorted(recomendations, key=lambda x: x[2]*x[3], reverse=True)
    return sorted_recomendations

# %%
print(baskets[1])
generate_basic_candidates(baskets[1], products, supports)
generate_advanced_candidates(baskets[1], products, supports)
# Out:
# {'sausage', 'yogurt', 'semi-finished bread', 'whole milk'}
# [('rolls/buns',
#   ('sausage', 'semi-finished bread'),
#   0.17398837209302326,
#   9.09052247873633),
#  ('other vegetables',
#   ('sausage', 'semi-finished bread'),
#   0.17398837209302326,
#   8.189928845101258),
#  ('other vegetables',
#   ('yogurt', 'semi-finished bread'),
#   0.17398837209302326,
#   8.189928845101258),
#  ('meat',
#   ('sausage', 'semi-finished bread'),
#   0.018333718391745822,
#   59.376984126984134),
#  ('butter milk',
#   ('sausage', 'semi-finished bread'),
#   0.018333718391745822,
#   56.893536121673),
#  ('sugar',
#   ('sausage', 'semi-finished bread'),
#   0.018333718391745822,
#   56.46415094339622),
#  ('long life bakery product',
#   ('sausage', 'semi-finished bread'),
#   0.018333718391745822,
#   55.832089552238806),
#  ('waffles',
#   ('sausage', 'semi-finished bread'),
#   0.018333718391745822,
#   54.018050541516246),
#  ('onions',
#   ('sausage', 'semi-finished bread'),
#   0.018333718391745822,
#   49.382838283828384),
#  ('uht-milk',
#   ('sausage', 'semi-finished bread'),
#   0.018333718391745822,
#   46.759375),
#  ('other vegetables',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   0.10413552046511629,
#   8.189928845101258),
#  ('berries',
#   ('sausage', 'semi-finished bread'),
#   0.018333718391745822,
#   45.898773006134974),
#  ('hamburger meat',
#   ('sausage', 'semi-finished bread'),
#   0.018333718391745822,
#   45.75840978593272),
#  ('napkins',
#   ('sausage', 'semi-finished bread'),
#   0.018333718391745822,
#   45.20543806646526),
#  ('chocolate',
#   ('sausage', 'semi-finished bread'),
#   0.018333718391745822,
#   42.388101983002834),
#  ('cream cheese ',
#   ('sausage', 'semi-finished bread'),
#   0.018333718391745822,
#   42.26836158192091),
#  ('white bread',
#   ('sausage', 'semi-finished bread'),
#   0.018333718391745822,
#   41.67966573816156),
#  ('meat', ('semi-finished bread',), 0.1053732394366197, 6.256745165437067),
#  ('chicken',
#   ('sausage', 'semi-finished bread'),
#   0.018333718391745822,
#   35.882494004796165),
#  ('ham', ('semi-finished bread',), 0.1053732394366197, 6.158983522227112),
#  ('butter milk',
#   ('semi-finished bread',),
#   0.1053732394366197,
#   5.995056204145022),
#  ('sugar', ('semi-finished bread',), 0.1053732394366197, 5.949810496943927),
#  ('long life bakery product',
#   ('semi-finished bread',),
#   0.1053732394366197,
#   5.883208140634854),
#  ('waffles', ('semi-finished bread',), 0.1053732394366197, 5.692056973610617),
#  ('other vegetables',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   0.07082635421452432,
#   8.189928845101258),
#  ('other vegetables',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   0.07082635421452432,
#   8.189928845101258),
#  ('other vegetables',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   0.07082635421452432,
#   8.189928845101258),
#  ('coffee',
#   ('sausage', 'semi-finished bread'),
#   0.018333718391745822,
#   31.63424947145877),
#  ('margarine',
#   ('sausage', 'semi-finished bread'),
#   0.018333718391745822,
#   31.04356846473029),
#  ('onions', ('semi-finished bread',), 0.1053732394366197, 5.203629642541719),
#  ('beef',
#   ('sausage', 'semi-finished bread'),
#   0.018333718391745822,
#   29.45472440944882),
#  ('fruit/vegetable juice',
#   ('sausage', 'semi-finished bread'),
#   0.018333718391745822,
#   29.396856581532415),
#  ('butter',
#   ('sausage', 'semi-finished bread'),
#   0.018333718391745822,
#   28.39278937381404),
#  ('uht-milk', ('semi-finished bread',), 0.1053732394366197, 4.927186817781689),
#  ('other vegetables',
#   ('semi-finished bread', 'whole milk'),
#   0.10413552046511629,
#   4.901836212370005),
#  ('berries', ('semi-finished bread',), 0.1053732394366197, 4.8365023978225175),
#  ('hamburger meat',
#   ('semi-finished bread',),
#   0.1053732394366197,
#   4.821711870612051),
#  ('napkins', ('semi-finished bread',), 0.1053732394366197, 4.763443449214927),
#  ('domestic eggs',
#   ('sausage', 'semi-finished bread'),
#   0.018333718391745822,
#   26.960360360360358),
#  ('pork',
#   ('sausage', 'semi-finished bread'),
#   0.018333718391745822,
#   26.960360360360358),
#  ('brown bread',
#   ('sausage', 'semi-finished bread'),
#   0.018333718391745822,
#   26.57726465364121),
#  ('frankfurter',
#   ('sausage', 'semi-finished bread'),
#   0.018333718391745822,
#   26.483185840707964),
#  ('newspapers',
#   ('sausage', 'semi-finished bread'),
#   0.018333718391745822,
#   25.709621993127147),
#  ('chocolate',
#   ('semi-finished bread',),
#   0.1053732394366197,
#   4.466571619518812),
#  ('cream cheese ',
#   ('semi-finished bread',),
#   0.1053732394366197,
#   4.45395418556537),
#  ('white bread',
#   ('semi-finished bread',),
#   0.1053732394366197,
#   4.391921397465573),
#  ('whipped/sour cream',
#   ('sausage', 'semi-finished bread'),
#   0.018333718391745822,
#   22.87920489296636),
#  ('chicken', ('semi-finished bread',), 0.1053732394366197, 3.7810546323504575),
#  ('other vegetables',
#   ('sausage', 'yogurt', 'whole milk'),
#   0.07082635421452432,
#   5.570268423147734),
#  ('canned beer',
#   ('sausage', 'semi-finished bread'),
#   0.018333718391745822,
#   21.314814814814813),
#  ('shopping bags',
#   ('sausage', 'semi-finished bread'),
#   0.018333718391745822,
#   21.015449438202246),
#  ('pip fruit',
#   ('sausage', 'semi-finished bread'),
#   0.018333718391745822,
#   20.385558583106267),
#  ('coffee', ('semi-finished bread',), 0.1053732394366197, 3.3334033439537856),
#  ('margarine',
#   ('semi-finished bread',),
#   0.1053732394366197,
#   3.271161372801122),
#  ('beef', ('semi-finished bread',), 0.1053732394366197, 3.1037397277364978),
#  ('fruit/vegetable juice',
#   ('semi-finished bread',),
#   0.1053732394366197,
#   3.0976420072497857),
#  ('butter', ('semi-finished bread',), 0.1053732394366197, 2.9918401929604186),
#  ('bottled water',
#   ('sausage', 'semi-finished bread'),
#   0.018333718391745822,
#   16.479074889867842),
#  ('domestic eggs',
#   ('semi-finished bread',),
#   0.1053732394366197,
#   2.8409005075498035),
#  ('pork', ('semi-finished bread',), 0.1053732394366197, 2.8409005075498035),
#  ('brown bread',
#   ('semi-finished bread',),
#   0.1053732394366197,
#   2.8005324719185447),
#  ('frankfurter',
#   ('semi-finished bread',),
#   0.1053732394366197,
#   2.7906190826374173),
#  ('newspapers',
#   ('semi-finished bread',),
#   0.1053732394366197,
#   2.709106154106771),
#  ('rolls/buns',
#   ('sausage', 'yogurt'),
#   0.17398837209302326,
#   1.5816452075503686),
#  ('baby cosmetics', ('sausage',), 0.0165703211517165, 16.5703211517165),
#  ('bags', ('sausage',), 0.0165703211517165, 16.5703211517165),
#  ('cream', ('sausage',), 0.0165703211517165, 16.5703211517165),
#  ('decalcifier', ('sausage',), 0.0165703211517165, 16.5703211517165),
#  ('frozen chicken', ('sausage',), 0.0165703211517165, 16.5703211517165),
#  ('frozen fruits', ('sausage',), 0.0165703211517165, 16.5703211517165),
#  ('hair spray', ('sausage',), 0.0165703211517165, 16.5703211517165),
#  ('honey', ('sausage',), 0.0165703211517165, 16.5703211517165),
#  ('kitchen utensil', ('sausage',), 0.0165703211517165, 16.5703211517165),
#  ('liqueur', ('sausage',), 0.0165703211517165, 16.5703211517165),
#  ('make up remover', ('sausage',), 0.0165703211517165, 16.5703211517165),
#  ('organic products', ('sausage',), 0.0165703211517165, 16.5703211517165),
#  ('preservation products', ('sausage',), 0.0165703211517165, 16.5703211517165),
#  ('rubbing alcohol', ('sausage',), 0.0165703211517165, 16.5703211517165),
#  ('salad dressing', ('sausage',), 0.0165703211517165, 16.5703211517165),
#  ('specialty vegetables', ('sausage',), 0.0165703211517165, 16.5703211517165),
#  ('toilet cleaner', ('sausage',), 0.0165703211517165, 16.5703211517165),
#  ('whisky', ('sausage',), 0.0165703211517165, 16.5703211517165),
#  ('cooking chocolate', ('sausage',), 0.0165703211517165, 16.5294476928756),
#  ('ready soups', ('sausage',), 0.0165703211517165, 16.5294476928756),
#  ('tropical fruit',
#   ('sausage', 'semi-finished bread'),
#   0.018333718391745822,
#   14.756410256410257),
#  ('root vegetables',
#   ('sausage', 'semi-finished bread'),
#   0.018333718391745822,
#   14.373679154658982),
#  ('cocoa drinks', ('sausage',), 0.0165703211517165, 15.496357212070873),
#  ('flower soil/fertilizer',
#   ('sausage',),
#   0.0165703211517165,
#   15.496357212070873),
#  ('whipped/sour cream',
#   ('semi-finished bread',),
#   0.1053732394366197,
#   2.4108559353060257),
#  ('other vegetables',
#   ('sausage', 'yogurt'),
#   0.17398837209302326,
#   1.424952387316862),
#  ('bathroom cleaner', ('sausage',), 0.0165703211517165, 14.584806787831411),
#  ('cookware', ('sausage',), 0.0165703211517165, 14.584806787831411),
#  ('pudding powder', ('sausage',), 0.0165703211517165, 14.584806787831411),
#  ('canned beer',
#   ('semi-finished bread',),
#   0.1053732394366197,
#   2.2460110850286905),
#  ('shopping bags',
#   ('semi-finished bread',),
#   0.1053732394366197,
#   2.2144659855198605),
#  ('pip fruit',
#   ('semi-finished bread',),
#   0.1053732394366197,
#   2.1480923456268948),
#  ('prosecco', ('sausage',), 0.0165703211517165, 13.049563968059685),
#  ('skin care', ('sausage',), 0.0165703211517165, 12.3970857696567),
#  ('soap', ('sausage',), 0.0165703211517165, 12.3970857696567),
#  ('rolls/buns',
#   ('yogurt', 'semi-finished bread'),
#   0.02207315168344325,
#   9.09052247873633),
#  ('canned fruit', ('sausage',), 0.0165703211517165, 11.806748352053999),
#  ('syrup', ('sausage',), 0.0165703211517165, 11.806748352053999),
#  ('meat', ('sausage', 'yogurt'), 0.018333718391745822, 10.33090480804725),
#  ('abrasive cleaner', ('sausage',), 0.0165703211517165, 11.270077972415182),
#  ('nut snack', ('sausage',), 0.0165703211517165, 11.270077972415182),
#  ('organic sausage', ('sausage',), 0.0165703211517165, 11.270077972415182),
#  ('tidbits', ('sausage',), 0.0165703211517165, 11.270077972415182),
#  ('bottled water',
#   ('semi-finished bread',),
#   0.1053732394366197,
#   1.7364535040640319),
#  ('butter milk',
#   ('sausage', 'yogurt'),
#   0.018333718391745822,
#   9.898813732425502),
#  ('sugar', ('sausage', 'yogurt'), 0.018333718391745822, 9.824105704256253),
#  ('potato products', ('sausage',), 0.0165703211517165, 10.780074582310172),
#  ('long life bakery product',
#   ('sausage', 'yogurt'),
#   0.018333718391745822,
#   9.714134371745923),
#  ('waffles', ('sausage', 'yogurt'), 0.018333718391745822, 9.398512677357067),
#  ('tropical fruit',
#   ('semi-finished bread',),
#   0.1053732394366197,
#   1.554930751173709),
#  ('root vegetables',
#   ('semi-finished bread',),
#   0.1053732394366197,
#   1.5146011351490305),
#  ('onions', ('sausage', 'yogurt'), 0.018333718391745822, 8.592039642336326),
#  ('snack products', ('sausage',), 0.0165703211517165, 9.183026496041998),
#  ('tea', ('sausage',), 0.0165703211517165, 9.183026496041998),
#  ('uht-milk', ('sausage', 'yogurt'), 0.018333718391745822, 8.13558753633721),
#  ('berries', ('sausage', 'yogurt'), 0.018333718391745822, 7.985852796404622),
#  ('hamburger meat',
#   ('sausage', 'yogurt'),
#   0.018333718391745822,
#   7.9614312282199),
#  ('napkins', ('sausage', 'yogurt'), 0.018333718391745822, 7.865220578936276),
#  ('artif. sweetener', ('sausage',), 0.0165703211517165, 8.549714323901172),
#  ('fish', ('sausage',), 0.0165703211517165, 8.549714323901172),
#  ('light bulbs', ('sausage',), 0.0165703211517165, 8.549714323901172),
#  ('specialty fat', ('sausage',), 0.0165703211517165, 8.549714323901172),
#  ('kitchen towels', ('sausage',), 0.0165703211517165, 8.2647238464378),
#  ('chocolate',
#   ('sausage', 'yogurt'),
#   0.018333718391745822,
#   7.3750368601357135),
#  ('cream cheese ',
#   ('sausage', 'yogurt'),
#   0.018333718391745822,
#   7.354203422677703),
#  ('white bread',
#   ('sausage', 'yogurt'),
#   0.018333718391745822,
#   7.251777191164087),
#  ('cleaner', ('sausage',), 0.0165703211517165, 7.99811985139142),
#  ('ketchup', ('sausage',), 0.0165703211517165, 7.748178606035436),
#  ('rum', ('sausage',), 0.0165703211517165, 7.748178606035436),
#  ('dental care', ('sausage',), 0.0165703211517165, 7.513385314943455),
#  ('nuts/prunes', ('sausage',), 0.0165703211517165, 7.513385314943455),
#  ('meat',
#   ('yogurt', 'semi-finished bread'),
#   0.0020472196141469606,
#   59.376984126984134),
#  ('jam', ('sausage',), 0.0165703211517165, 7.292403393915706),
#  ('meat spreads', ('sausage',), 0.0165703211517165, 7.084049011232401),
#  ('butter milk',
#   ('yogurt', 'semi-finished bread'),
#   0.0020472196141469606,
#   56.893536121673),
#  ('sugar',
#   ('yogurt', 'semi-finished bread'),
#   0.0020472196141469606,
#   56.46415094339622),
#  ('chicken', ('sausage', 'yogurt'), 0.018333718391745822, 6.243136718532151),
#  ('long life bakery product',
#   ('yogurt', 'semi-finished bread'),
#   0.0020472196141469606,
#   55.832089552238806),
#  ('male cosmetics', ('sausage',), 0.0165703211517165, 6.7011274430576755),
#  ('waffles',
#   ('yogurt', 'semi-finished bread'),
#   0.0020472196141469606,
#   54.018050541516246),
#  ('brandy', ('sausage',), 0.0165703211517165, 6.524781984029842),
#  ('female sanitary products',
#   ('sausage',),
#   0.0165703211517165,
#   6.19854288482835),
#  ('spices', ('sausage',), 0.0165703211517165, 6.19854288482835),
#  ('onions',
#   ('yogurt', 'semi-finished bread'),
#   0.0020472196141469606,
#   49.382838283828384),
#  ('coffee', ('sausage', 'yogurt'), 0.018333718391745822, 5.503991567923693),
#  ('softener', ('sausage',), 0.0165703211517165, 6.047358912027659),
#  ('soda', ('sausage',), 0.09856035437430785, 1.0149749363405152),
#  ('margarine', ('sausage', 'yogurt'), 0.018333718391745822, 5.401219941136736),
#  ('cereals', ('sausage',), 0.0165703211517165, 5.9033741760269995),
#  ('uht-milk',
#   ('yogurt', 'semi-finished bread'),
#   0.0020472196141469606,
#   46.759375),
#  ('berries',
#   ('yogurt', 'semi-finished bread'),
#   0.0020472196141469606,
#   45.898773006134974),
#  ('beef', ('sausage', 'yogurt'), 0.018333718391745822, 5.124779550448636),
#  ('fruit/vegetable juice',
#   ('sausage', 'yogurt'),
#   0.018333718391745822,
#   5.114711221272902),
#  ('hamburger meat',
#   ('yogurt', 'semi-finished bread'),
#   0.0020472196141469606,
#   45.75840978593272),
#  ('sauces', ('sausage',), 0.0165703211517165, 5.635038986207591),
#  ('napkins',
#   ('yogurt', 'semi-finished bread'),
#   0.0020472196141469606,
#   45.20543806646526),
#  ('house keeping products',
#   ('sausage',),
#   0.0165703211517165,
#   5.5098158976252005),
#  ('butter', ('sausage', 'yogurt'), 0.018333718391745822, 4.940015202329994),
#  ('curd cheese', ('sausage',), 0.0165703211517165, 5.390037291155086),
#  ('sparkling wine', ('sausage',), 0.0165703211517165, 5.390037291155086),
#  ('chocolate',
#   ('yogurt', 'semi-finished bread'),
#   0.0020472196141469606,
#   42.388101983002834),
#  ('cream cheese ',
#   ('yogurt', 'semi-finished bread'),
#   0.0020472196141469606,
#   42.26836158192091),
#  ('domestic eggs',
#   ('sausage', 'yogurt'),
#   0.018333718391745822,
#   4.690789210140373),
#  ('pork', ('sausage', 'yogurt'), 0.018333718391745822, 4.690789210140373),
#  ('popcorn', ('sausage',), 0.0165703211517165, 5.165452404023625),
#  ('soups', ('sausage',), 0.0165703211517165, 5.165452404023625),
#  ('white bread',
#   ('yogurt', 'semi-finished bread'),
#   0.0020472196141469606,
#   41.67966573816156),
#  ('brown bread',
#   ('sausage', 'yogurt'),
#   0.018333718391745822,
#   4.6241350117724815),
#  ('frankfurter',
#   ('sausage', 'yogurt'),
#   0.018333718391745822,
#   4.607766392261783),
#  ('rice', ('sausage',), 0.0165703211517165, 5.060035008023142),
#  ('liver loaf', ('sausage',), 0.0165703211517165, 4.95883430786268),
#  ('newspapers',
#   ('sausage', 'yogurt'),
#   0.018333718391745822,
#   4.473175277711181),
#  ('vinegar', ('sausage',), 0.0165703211517165, 4.861602262610471),
#  ('chicken',
#   ('yogurt', 'semi-finished bread'),
#   0.0020472196141469606,
#   35.882494004796165),
#  ('whipped/sour cream',
#   ('sausage', 'yogurt'),
#   0.018333718391745822,
#   3.98071561410995),
#  ('curd', ('sausage',), 0.04872646733111849, 1.4466153386419167),
#  ('instant coffee', ('sausage',), 0.0165703211517165, 4.20240195581583),
#  ('chocolate marshmallow', ('sausage',), 0.0165703211517165, 4.1323619232189),
#  ('instant food products', ('sausage',), 0.0165703211517165, 4.1323619232189),
#  ('zwieback', ('sausage',), 0.0165703211517165, 4.1323619232189),
#  ('canned beer',
#   ('sausage', 'yogurt'),
#   0.018333718391745822,
#   3.708529931093885),
#  ('bottled beer', ('sausage',), 0.05537098560354374, 1.2220000849348451),
#  ('shopping bags',
#   ('sausage', 'yogurt'),
#   0.018333718391745822,
#   3.656443836556049),
#  ('pip fruit',
#   ('sausage', 'yogurt'),
#   0.018333718391745822,
#   3.5468501520816167),
#  ('coffee',
#   ('yogurt', 'semi-finished bread'),
#   0.0020472196141469606,
#   31.63424947145877),
#  ('finished products', ('sausage',), 0.0165703211517165, 3.874089303017718),
#  ('margarine',
#   ('yogurt', 'semi-finished bread'),
#   0.0020472196141469606,
#   31.04356846473029),
#  ('candles', ('sausage',), 0.0165703211517165, 3.7566926574717274),
#  ('dog food', ('sausage',), 0.0165703211517165, 3.70062261780797),
#  ('liquor (appetizer)', ('sausage',), 0.0165703211517165, 3.70062261780797),
#  ('sweet spreads', ('sausage',), 0.0165703211517165, 3.646201696957853),
#  ('beef',
#   ('yogurt', 'semi-finished bread'),
#   0.0020472196141469606,
#   29.45472440944882),
#  ('fruit/vegetable juice',
#   ('yogurt', 'semi-finished bread'),
#   0.0020472196141469606,
#   29.396856581532415),
#  ('flower (seeds)', ('sausage',), 0.0165703211517165, 3.593358194103391),
#  ('butter',
#   ('yogurt', 'semi-finished bread'),
#   0.0020472196141469606,
#   28.39278937381404),
#  ('frozen potato products',
#   ('sausage',),
#   0.0165703211517165,
#   3.4436349360157497),
#  ('specialty cheese', ('sausage',), 0.0165703211517165, 3.4436349360157497),
#  ('dish cleaner', ('sausage',), 0.0165703211517165, 3.3964618547004655),
#  ('cling film/bags', ('sausage',), 0.0165703211517165, 3.3505637215288377),
#  ('domestic eggs',
#   ('yogurt', 'semi-finished bread'),
#   0.0020472196141469606,
#   26.960360360360358),
#  ('pork',
#   ('yogurt', 'semi-finished bread'),
#   0.0020472196141469606,
#   26.960360360360358),
#  ('mayonnaise', ('sausage',), 0.0165703211517165, 3.30588953857512),
#  ('pastry', ('sausage',), 0.05315614617940199, 1.0276168156103256),
#  ('brown bread',
#   ('yogurt', 'semi-finished bread'),
#   0.0020472196141469606,
#   26.57726465364121),
#  ('citrus fruit', ('yogurt',), 0.053696498054474705, 1.0106423904265471),
#  ('frankfurter',
#   ('yogurt', 'semi-finished bread'),
#   0.0020472196141469606,
#   26.483185840707964),
#  ('newspapers',
#   ('yogurt', 'semi-finished bread'),
#   0.0020472196141469606,
#   25.709621993127147),
#  ('bottled water',
#   ('sausage', 'yogurt'),
#   0.018333718391745822,
#   2.867167413687122),
#  ('photo/film', ('sausage',), 0.0165703211517165, 3.138502726495367),
#  ('turkey', ('sausage',), 0.0165703211517165, 3.099271442414175),
#  ('canned vegetables', ('sausage',), 0.0165703211517165, 3.0236794560138294),
#  ('roll products ', ('sausage',), 0.0165703211517165, 3.0236794560138294),
#  ('pet care', ('sausage',), 0.0165703211517165, 2.9169613575662825),
#  ('tropical fruit',
#   ('sausage', 'yogurt'),
#   0.018333718391745822,
#   2.5674437984496126),
#  ('whipped/sour cream',
#   ('yogurt', 'semi-finished bread'),
#   0.0020472196141469606,
#   22.87920489296636),
#  ('salt', ('sausage',), 0.0165703211517165, 2.7858619707093712),
#  ('root vegetables',
#   ('sausage', 'yogurt'),
#   0.018333718391745822,
#   2.500853037106539),
#  ('cake bar', ('sausage',), 0.0165703211517165, 2.695018645577543),
#  ('frozen dessert', ('sausage',), 0.0165703211517165, 2.695018645577543),
#  ('mustard', ('sausage',), 0.0165703211517165, 2.695018645577543),
#  ('canned beer',
#   ('yogurt', 'semi-finished bread'),
#   0.0020472196141469606,
#   21.314814814814813),
#  ('shopping bags',
#   ('yogurt', 'semi-finished bread'),
#   0.0020472196141469606,
#   21.015449438202246),
#  ('frozen vegetables', ('sausage',), 0.03433001107419712, 1.2259664813919129),
#  ('condensed milk', ('sausage',), 0.0165703211517165, 2.530017504011571),
#  ('pip fruit',
#   ('yogurt', 'semi-finished bread'),
#   0.0020472196141469606,
#   20.385558583106267),
#  ('spread cheese', ('sausage',), 0.0165703211517165, 2.47941715393134),
#  ('frozen fish', ('sausage',), 0.0165703211517165, 2.4308011313052353),
#  ('liquor', ('sausage',), 0.0165703211517165, 2.407201120321689),
#  ('beverages', ('sausage',), 0.02547065337763012, 1.5367636551995143),
#  ('seasonal products', ('sausage',), 0.0165703211517165, 2.3390727867276793),
#  ('canned fish', ('sausage',), 0.0165703211517165, 2.1560149164620346),
#  ('pot plants', ('sausage',), 0.0165703211517165, 2.1191599606250766),
#  ('baking powder', ('sausage',), 0.0165703211517165, 2.0491050858936695),
#  ('pasta', ('sausage',), 0.0165703211517165, 2.0491050858936695),
#  ('bottled water',
#   ('yogurt', 'semi-finished bread'),
#   0.0020472196141469606,
#   16.479074889867842),
#  ('packaged fruit/vegetables',
#   ('sausage',),
#   0.0165703211517165,
#   1.9522969715994805),
#  ('detergent', ('sausage',), 0.0165703211517165, 1.9220288014971625),
#  ('pickled vegetables', ('sausage',), 0.0165703211517165, 1.850311308903985),
#  ('dishes', ('sausage',), 0.0165703211517165, 1.8366052992083999),
#  ('tropical fruit',
#   ('yogurt', 'semi-finished bread'),
#   0.0020472196141469606,
#   14.756410256410257),
#  ('root vegetables',
#   ('yogurt', 'semi-finished bread'),
#   0.0020472196141469606,
#   14.373679154658982),
#  ('beverages',
#   ('sausage', 'semi-finished bread'),
#   0.0004669717862792402,
#   60.33467741935484),
#  ('flour', ('sausage',), 0.0165703211517165, 1.6982309273502327),
#  ('soft cheese', ('sausage',), 0.0165703211517165, 1.65294476928756),
#  ('processed cheese', ('sausage',), 0.0165703211517165, 1.6311954960074606),
#  ('curd',
#   ('sausage', 'semi-finished bread'),
#   0.0008933373302733289,
#   29.688492063492067),
#  ('frozen meals', ('sausage',), 0.02104097452934662, 1.2543270991339184),
#  ('red/blush wine', ('sausage',), 0.0165703211517165, 1.579246594860726),
#  ('herbs', ('sausage',), 0.0165703211517165, 1.5692513632476834),
#  ('white wine',
#   ('sausage', 'semi-finished bread'),
#   0.0003037956016563596,
#   85.50285714285714),
#  ('cat food',
#   ('sausage', 'semi-finished bread'),
#   0.0003037956016563596,
#   84.53672316384181),
#  ('rolls/buns',
#   ('sausage', 'whole milk'),
#   0.02207315168344325,
#   1.1532752398396837),
#  ('sliced cheese', ('sausage',), 0.018826135105204873, 1.34140695037705),
#  ('dessert', ('sausage',), 0.024363233665559245, 1.0327112332514532),
#  ('sliced cheese',
#   ('sausage', 'semi-finished bread'),
#   0.0003451530594237862,
#   71.25238095238095),
#  ('white wine', ('sausage',), 0.0165703211517165, 1.41680980224648),
#  ('cat food', ('sausage',), 0.0165703211517165, 1.40080065193861),
#  ('frozen meals',
#   ('sausage', 'semi-finished bread'),
#   0.00038575930170893746,
#   59.61354581673307),
#  ('chewing gum', ('sausage',), 0.0165703211517165, 1.3774539744063001),
#  ('grapes',
#   ('sausage', 'semi-finished bread'),
#   0.0003248499382812106,
#   69.27314814814814),
#  ('frozen vegetables',
#   ('sausage', 'semi-finished bread'),
#   0.0006293967554198454,
#   35.71121718377088),
#  ('bottled beer',
#   ('sausage', 'semi-finished bread'),
#   0.001015156057128783,
#   22.0693215339233),
#  ('hygiene articles',
#   ('sausage', 'semi-finished bread'),
#   0.0003037956016563596,
#   72.99024390243903),
#  ('grapes', ('sausage',), 0.017718715393134, 1.2274311964234446),
#  ('candy',
#   ('sausage', 'semi-finished bread'),
#   0.0003037956016563596,
#   69.5953488372093),
#  ('misc. beverages',
#   ('sausage', 'semi-finished bread'),
#   0.0003248499382812106,
#   63.40254237288135),
#  ('oil',
#   ('sausage', 'semi-finished bread'),
#   0.0003037956016563596,
#   67.09865470852017),
#  ('hygiene articles', ('sausage',), 0.0165703211517165, 1.2094717824055317),
#  ('ice cream',
#   ('sausage', 'semi-finished bread'),
#   0.0003037956016563596,
#   65.91629955947137),
#  ('misc. beverages', ('sausage',), 0.017718715393134, 1.1234116035062036),
#  ('specialty bar', ('sausage',), 0.0165703211517165, 1.1863239970963348),
#  ('candy', ('sausage',), 0.0165703211517165, 1.1532172808982977),
#  ('specialty chocolate',
#   ('sausage', 'semi-finished bread'),
#   0.0003037956016563596,
#   62.60669456066946),
#  ('dessert',
#   ('sausage', 'semi-finished bread'),
#   0.00044666866513666444,
#   42.388101983002834),
#  ('salty snack', ('sausage',), 0.018826135105204873, 1.002474945121639),
#  ('pastry',
#   ('sausage', 'semi-finished bread'),
#   0.0009745498148436316,
#   19.332041343669253),
#  ('hard cheese', ('sausage',), 0.0165703211517165, 1.1270077972415182),
#  ('soda',
#   ('sausage', 'semi-finished bread'),
#   0.0018069777816892337,
#   10.298004129387476),
#  ('ham',
#   ('sausage', 'semi-finished bread'),
#   0.0003181051434877608,
#   58.44921875),
#  ('citrus fruit',
#   ('sausage', 'semi-finished bread'),
#   0.0009844564739536668,
#   18.82138364779874),
#  ('oil', ('sausage',), 0.0165703211517165, 1.1118462573683139),
#  ('salty snack',
#   ('sausage', 'semi-finished bread'),
#   0.0003451530594237862,
#   53.2491103202847),
#  ('ice cream', ('sausage',), 0.0165703211517165, 1.0922542528331893),
#  ('specialty chocolate', ('sausage',), 0.0165703211517165, 1.0374130351177155),
#  ('beverages',
#   ('semi-finished bread',),
#   0.0026839252569681653,
#   6.35766041004089),
#  ('curd', ('semi-finished bread',), 0.005134465708982576, 3.1283725827185336),
#  ('white wine',
#   ('semi-finished bread',),
#   0.0017460684182615067,
#   9.009713038229377),
#  ('cat food',
#   ('semi-finished bread',),
#   0.0017460684182615067,
#   8.90790837113074),
#  ('sliced cheese',
#   ('semi-finished bread',),
#   0.0019837708421069048,
#   7.508094198524479),
#  ('rolls/buns',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   0.0015821823647394558,
#   9.09052247873633),
#  ('frozen meals',
#   ('semi-finished bread',),
#   0.002217155647060658,
#   6.281672437012514),
#  ('grapes',
#   ('semi-finished bread',),
#   0.0018670784396300282,
#   7.299536026343244),
#  ('frozen vegetables',
#   ('semi-finished bread',),
#   0.0036174644767831793,
#   3.763006638878617),
#  ('meat', ('sausage', 'whole milk'), 0.0020472196141469606, 6.630282190239281),
#  ('bottled beer',
#   ('semi-finished bread',),
#   0.0058346201238438375,
#   2.3255159021978478),
#  ('hygiene articles',
#   ('semi-finished bread',),
#   0.0017460684182615067,
#   7.69121844726898),
#  ('butter milk',
#   ('sausage', 'whole milk'),
#   0.0020472196141469606,
#   6.352970007377561),
#  ('sugar',
#   ('sausage', 'whole milk'),
#   0.0020472196141469606,
#   6.305023063925654),
#  ('candy',
#   ('semi-finished bread',),
#   0.0017460684182615067,
#   7.3334873566983285),
#  ('long life bakery product',
#   ('sausage', 'whole milk'),
#   0.0020472196141469606,
#   6.234444447538427),
#  ('misc. beverages',
#   ('semi-finished bread',),
#   0.0018670784396300282,
#   6.680931278348053),
#  ('waffles',
#   ('sausage', 'whole milk'),
#   0.0020472196141469606,
#   6.031881270542595),
#  ('oil', ('semi-finished bread',), 0.0017460684182615067, 7.070402608475967),
#  ('ice cream',
#   ('semi-finished bread',),
#   0.0017460684182615067,
#   6.9458140162561275),
#  ('specialty chocolate',
#   ('semi-finished bread',),
#   0.0017460684182615067,
#   6.597070216276739),
#  ('dessert',
#   ('semi-finished bread',),
#   0.002567232854491288,
#   4.466571619518812),
#  ('pastry',
#   ('semi-finished bread',),
#   0.005601235318890083,
#   2.0370798213050914),
#  ('onions',
#   ('sausage', 'whole milk'),
#   0.0020472196141469606,
#   5.514294098812866),
#  ('soda', ('semi-finished bread',), 0.01038562382044203, 1.085134054845245),
#  ('citrus fruit',
#   ('semi-finished bread',),
#   0.0056581739464021475,
#   1.9832701656479759),
#  ('salty snack',
#   ('semi-finished bread',),
#   0.0019837708421069048,
#   5.611031251566337),
#  ('uht-milk',
#   ('sausage', 'whole milk'),
#   0.0020472196141469606,
#   5.2213472248134325),
#  ('berries',
#   ('sausage', 'whole milk'),
#   0.0020472196141469606,
#   5.125248809632818),
#  ('hamburger meat',
#   ('sausage', 'whole milk'),
#   0.0020472196141469606,
#   5.109575265872473),
#  ('napkins',
#   ('sausage', 'whole milk'),
#   0.0020472196141469606,
#   5.047828132750147),
#  ('rolls/buns',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   0.0010760997601634763,
#   9.09052247873633),
#  ('rolls/buns',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   0.0010760997601634763,
#   9.09052247873633),
#  ('rolls/buns',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   0.0010760997601634763,
#   9.09052247873633),
#  ('chocolate',
#   ('sausage', 'whole milk'),
#   0.0020472196141469606,
#   4.733232611728891),
#  ('cream cheese ',
#   ('sausage', 'whole milk'),
#   0.0020472196141469606,
#   4.719861898136437),
#  ('white bread',
#   ('sausage', 'whole milk'),
#   0.0020472196141469606,
#   4.654125660000831),
#  ('rolls/buns',
#   ('semi-finished bread', 'whole milk'),
#   0.0015821823647394558,
#   5.440859513973269),
#  ('chicken',
#   ('sausage', 'whole milk'),
#   0.0020472196141469606,
#   4.006789237266903),
#  ('coffee',
#   ('sausage', 'whole milk'),
#   0.0020472196141469606,
#   3.5324124988166985),
#  ('margarine',
#   ('sausage', 'whole milk'),
#   0.0020472196141469606,
#   3.466454589087756),
#  ('beef', ('sausage', 'whole milk'), 0.0020472196141469606, 3.289037621929722),
#  ('fruit/vegetable juice',
#   ('sausage', 'whole milk'),
#   0.0020472196141469606,
#   3.282575858428878),
#  ('rolls/buns',
#   ('sausage', 'yogurt', 'whole milk'),
#   0.0010760997601634763,
#   6.182794902242351),
#  ('meat',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   0.0001097855813305425,
#   59.376984126984134),
#  ('butter',
#   ('sausage', 'whole milk'),
#   0.0020472196141469606,
#   3.1704575179132797),
#  ('butter milk',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   0.0001097855813305425,
#   56.893536121673),
#  ('sugar',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   0.0001097855813305425,
#   56.46415094339622),
#  ('domestic eggs',
#   ('sausage', 'whole milk'),
#   0.0020472196141469606,
#   3.0105065080005384),
#  ('pork',
#   ('sausage', 'whole milk'),
#   0.0020472196141469606,
#   3.0105065080005384),
#  ('long life bakery product',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   0.0001097855813305425,
#   55.832089552238806),
#  ('brown bread',
#   ('sausage', 'whole milk'),
#   0.0020472196141469606,
#   2.9677284403912942),
#  ('frankfurter',
#   ('sausage', 'whole milk'),
#   0.0020472196141469606,
#   2.95722320697398),
#  ('waffles',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   0.0001097855813305425,
#   54.018050541516246),
#  ('newspapers',
#   ('sausage', 'whole milk'),
#   0.0020472196141469606,
#   2.8708438349489667),
#  ('onions',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   0.0001097855813305425,
#   49.382838283828384),
#  ('whipped/sour cream',
#   ('sausage', 'whole milk'),
#   0.0020472196141469606,
#   2.5547876329362365),
#  ('uht-milk',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   0.0001097855813305425,
#   46.759375),
#  ('berries',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   0.0001097855813305425,
#   45.898773006134974),
#  ('hamburger meat',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   0.0001097855813305425,
#   45.75840978593272),
#  ('napkins',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   0.0001097855813305425,
#   45.20543806646526),
#  ('beverages',
#   ('sausage', 'yogurt'),
#   0.0004669717862792402,
#   10.497532304951239),
#  ('canned beer',
#   ('sausage', 'whole milk'),
#   0.0020472196141469606,
#   2.3801012990602546),
#  ('shopping bags',
#   ('sausage', 'whole milk'),
#   0.0020472196141469606,
#   2.3466729100285093),
#  ('pip fruit',
#   ('sausage', 'whole milk'),
#   0.0020472196141469606,
#   2.276336664768799),
#  ('chocolate',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   0.0001097855813305425,
#   42.388101983002834),
#  ('cream cheese ',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   0.0001097855813305425,
#   42.26836158192091),
#  ('curd', ('sausage', 'yogurt'), 0.0008933373302733289, 5.165452404023625),
#  ('white bread',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   0.0001097855813305425,
#   41.67966573816156),
#  ('white wine',
#   ('sausage', 'yogurt'),
#   0.0003037956016563596,
#   14.876502923588038),
#  ('cat food',
#   ('sausage', 'yogurt'),
#   0.0003037956016563596,
#   14.708406845355405),
#  ('meat',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   59.376984126984134),
#  ('meat',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   59.376984126984134),
#  ('meat',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   59.376984126984134),
#  ('sliced cheese',
#   ('sausage', 'yogurt'),
#   0.0003451530594237862,
#   12.397085769656698),
#  ('butter milk',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   56.893536121673),
#  ('butter milk',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   56.893536121673),
#  ('butter milk',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   56.893536121673),
#  ('sugar',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   56.46415094339622),
#  ('sugar',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   56.46415094339622),
#  ('sugar',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   56.46415094339622),
#  ('long life bakery product',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   55.832089552238806),
#  ('long life bakery product',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   55.832089552238806),
#  ('long life bakery product',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   55.832089552238806),
#  ('waffles',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   54.018050541516246),
#  ('waffles',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   54.018050541516246),
#  ('waffles',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   54.018050541516246),
#  ('frozen meals',
#   ('sausage', 'yogurt'),
#   0.00038575930170893746,
#   10.372063791346244),
#  ('chicken',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   0.0001097855813305425,
#   35.882494004796165),
#  ('grapes', ('sausage', 'yogurt'), 0.0003248499382812106, 12.052722276055125),
#  ('frozen vegetables',
#   ('sausage', 'yogurt'),
#   0.0006293967554198454,
#   6.213336543264694),
#  ('meat',
#   ('semi-finished bread', 'whole milk'),
#   0.0001097855813305425,
#   35.53831253968254),
#  ('bottled beer',
#   ('sausage', 'yogurt'),
#   0.001015156057128783,
#   3.839805326884818),
#  ('hygiene articles',
#   ('sausage', 'yogurt'),
#   0.0003037956016563596,
#   12.699453715258082),
#  ('bottled water',
#   ('sausage', 'whole milk'),
#   0.0020472196141469606,
#   1.840122369978302),
#  ('butter milk',
#   ('semi-finished bread', 'whole milk'),
#   0.0001097855813305425,
#   34.05191923954372),
#  ('sugar',
#   ('semi-finished bread', 'whole milk'),
#   0.0001097855813305425,
#   33.79492362264151),
#  ('onions',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   49.382838283828384),
#  ('onions',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   49.382838283828384),
#  ('onions',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   49.382838283828384),
#  ('candy', ('sausage', 'yogurt'), 0.0003037956016563596, 12.108781449432126),
#  ('long life bakery product',
#   ('semi-finished bread', 'whole milk'),
#   0.0001097855813305425,
#   33.41662223880597),
#  ('misc. beverages',
#   ('sausage', 'yogurt'),
#   0.0003248499382812106,
#   11.031305134016554),
#  ('waffles',
#   ('semi-finished bread', 'whole milk'),
#   0.0001097855813305425,
#   32.3308836101083),
#  ('oil', ('sausage', 'yogurt'), 0.0003037956016563596, 11.674385702367296),
#  ('uht-milk',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   46.759375),
#  ('uht-milk',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   46.759375),
#  ('uht-milk',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   46.759375),
#  ('ice cream',
#   ('sausage', 'yogurt'),
#   0.0003037956016563596,
#   11.468669654748489),
#  ('coffee',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   0.0001097855813305425,
#   31.63424947145877),
#  ('berries',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   45.898773006134974),
#  ('berries',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   45.898773006134974),
#  ('berries',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   45.898773006134974),
#  ('hamburger meat',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   45.75840978593272),
#  ('hamburger meat',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   45.75840978593272),
#  ('hamburger meat',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   45.75840978593272),
#  ('margarine',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   0.0001097855813305425,
#   31.04356846473029),
#  ('napkins',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   45.20543806646526),
#  ('napkins',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   45.20543806646526),
#  ('napkins',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   45.20543806646526),
#  ('tropical fruit',
#   ('sausage', 'whole milk'),
#   0.0020472196141469606,
#   1.6477624378109454),
#  ('specialty chocolate',
#   ('sausage', 'yogurt'),
#   0.0003037956016563596,
#   10.892836868736012),
#  ('dessert',
#   ('sausage', 'yogurt'),
#   0.00044666866513666444,
#   7.3750368601357135),
#  ('root vegetables',
#   ('sausage', 'whole milk'),
#   0.0020472196141469606,
#   1.6050250835161366),
#  ('pastry', ('sausage', 'yogurt'), 0.0009745498148436316, 3.363550402620035),
#  ('onions',
#   ('semi-finished bread', 'whole milk'),
#   0.0001097855813305425,
#   29.556616369636963),
#  ('soda', ('sausage', 'yogurt'), 0.0018069777816892337, 1.7917329742793582),
#  ('ham', ('sausage', 'yogurt'), 0.0003181051434877608, 10.16948442042151),
#  ('beef',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   0.0001097855813305425,
#   29.45472440944882),
#  ('fruit/vegetable juice',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   0.0001097855813305425,
#   29.396856581532415),
#  ('citrus fruit',
#   ('sausage', 'yogurt'),
#   0.0009844564739536668,
#   3.2747019014187506),
#  ('salty snack',
#   ('sausage', 'yogurt'),
#   0.0003451530594237862,
#   9.264726020028139),
#  ('chocolate',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   42.388101983002834),
#  ('chocolate',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   42.388101983002834),
#  ('chocolate',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   42.388101983002834),
#  ('cream cheese ',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   42.26836158192091),
#  ('cream cheese ',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   42.26836158192091),
#  ('cream cheese ',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   42.26836158192091),
#  ('beverages',
#   ('yogurt', 'semi-finished bread'),
#   5.214402117982292e-05,
#   60.33467741935484),
#  ('butter',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   0.0001097855813305425,
#   28.39278937381404),
#  ('white bread',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   41.67966573816156),
#  ('white bread',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   41.67966573816156),
#  ('white bread',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   41.67966573816156),
#  ('uht-milk',
#   ('semi-finished bread', 'whole milk'),
#   0.0001097855813305425,
#   27.986421125000003),
#  ('berries',
#   ('semi-finished bread', 'whole milk'),
#   0.0001097855813305425,
#   27.471333619631903),
#  ('meat',
#   ('sausage', 'yogurt', 'whole milk'),
#   7.466916606585943e-05,
#   40.384446067821074),
#  ('hamburger meat',
#   ('semi-finished bread', 'whole milk'),
#   0.0001097855813305425,
#   27.387323425076453),
#  ('napkins',
#   ('semi-finished bread', 'whole milk'),
#   0.0001097855813305425,
#   27.056358791540788),
#  ('curd',
#   ('yogurt', 'semi-finished bread'),
#   9.975377964835687e-05,
#   29.688492063492067),
#  ('domestic eggs',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   0.0001097855813305425,
#   26.960360360360358),
#  ('pork',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   0.0001097855813305425,
#   26.960360360360358),
#  ('brown bread',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   0.0001097855813305425,
#   26.57726465364121),
#  ('frankfurter',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   0.0001097855813305425,
#   26.483185840707964),
#  ('white wine',
#   ('yogurt', 'semi-finished bread'),
#   3.392308647450827e-05,
#   85.50285714285714),
#  ('butter milk',
#   ('sausage', 'yogurt', 'whole milk'),
#   7.466916606585943e-05,
#   38.69536277220878),
#  ('rolls/buns',
#   ('yogurt', 'whole milk'),
#   0.002643491219574042,
#   1.0886853267947703),
#  ('cat food',
#   ('yogurt', 'semi-finished bread'),
#   3.392308647450827e-05,
#   84.53672316384181),
#  ('sugar',
#   ('sausage', 'yogurt', 'whole milk'),
#   7.466916606585943e-05,
#   38.40332229845626),
#  ('long life bakery product',
#   ('sausage', 'yogurt', 'whole milk'),
#   7.466916606585943e-05,
#   37.97343436227951),
#  ('newspapers',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   0.0001097855813305425,
#   25.709621993127147),
#  ('chocolate',
#   ('semi-finished bread', 'whole milk'),
#   0.0001097855813305425,
#   25.370126798866856),
#  ('cream cheese ',
#   ('semi-finished bread', 'whole milk'),
#   0.0001097855813305425,
#   25.298459774011302),
#  ('sliced cheese',
#   ('yogurt', 'semi-finished bread'),
#   3.8541233045956064e-05,
#   71.25238095238095),
#  ('waffles',
#   ('sausage', 'yogurt', 'whole milk'),
#   7.466916606585943e-05,
#   36.739640466032164),
#  ('white bread',
#   ('semi-finished bread', 'whole milk'),
#   0.0001097855813305425,
#   24.946113537604457),
#  ('chicken',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   35.882494004796165),
#  ('chicken',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   35.882494004796165),
#  ('chicken',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   35.882494004796165),
#  ('frozen meals',
#   ('yogurt', 'semi-finished bread'),
#   4.3075495757245006e-05,
#   59.61354581673307),
#  ('grapes',
#   ('yogurt', 'semi-finished bread'),
#   3.62741016903116e-05,
#   69.27314814814814),
#  ('whipped/sour cream',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   0.0001097855813305425,
#   22.87920489296636),
#  ('frozen vegetables',
#   ('yogurt', 'semi-finished bread'),
#   7.028107202497871e-05,
#   35.71121718377088),
#  ('onions',
#   ('sausage', 'yogurt', 'whole milk'),
#   7.466916606585943e-05,
#   33.587064056405644),
#  ('bottled beer',
#   ('yogurt', 'semi-finished bread'),
#   0.00011335656778222372,
#   22.0693215339233),
#  ('hygiene articles',
#   ('yogurt', 'semi-finished bread'),
#   3.392308647450827e-05,
#   72.99024390243903),
#  ('uht-milk',
#   ('sausage', 'yogurt', 'whole milk'),
#   7.466916606585943e-05,
#   31.80275127840909),
#  ('coffee',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   31.63424947145877),
#  ('coffee',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   31.63424947145877),
#  ('coffee',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   31.63424947145877),
#  ('candy',
#   ('yogurt', 'semi-finished bread'),
#   3.392308647450827e-05,
#   69.5953488372093),
#  ('chicken',
#   ('semi-finished bread', 'whole milk'),
#   0.0001097855813305425,
#   21.4763903117506),
#  ('canned beer',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   0.0001097855813305425,
#   21.314814814814813),
#  ('berries',
#   ('sausage', 'yogurt', 'whole milk'),
#   7.466916606585943e-05,
#   31.21742456776353),
#  ('hamburger meat',
#   ('sausage', 'yogurt', 'whole milk'),
#   7.466916606585943e-05,
#   31.12195843758688),
#  ('margarine',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   31.04356846473029),
#  ('margarine',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   31.04356846473029),
#  ('margarine',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   31.04356846473029),
#  ('shopping bags',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   0.0001097855813305425,
#   21.015449438202246),
#  ('misc. beverages',
#   ('yogurt', 'semi-finished bread'),
#   3.62741016903116e-05,
#   63.40254237288135),
#  ('napkins',
#   ('sausage', 'yogurt', 'whole milk'),
#   7.466916606585943e-05,
#   30.74586226311453),
#  ('oil',
#   ('yogurt', 'semi-finished bread'),
#   3.392308647450827e-05,
#   67.09865470852017),
#  ('baby cosmetics', ('yogurt',), 0.00019295075127870347, 11.644357976653698),
#  ('bags', ('yogurt',), 0.00019295075127870347, 11.644357976653698),
#  ('cream', ('yogurt',), 0.00019295075127870347, 11.644357976653698),
#  ('decalcifier', ('yogurt',), 0.00019295075127870347, 11.644357976653698),
#  ('frozen chicken', ('yogurt',), 0.00019295075127870347, 11.644357976653698),
#  ('frozen fruits', ('yogurt',), 0.00019295075127870347, 11.644357976653698),
#  ('hair spray', ('yogurt',), 0.00019295075127870347, 11.644357976653698),
#  ('honey', ('yogurt',), 0.00019295075127870347, 11.644357976653698),
#  ('kitchen utensil', ('yogurt',), 0.00019295075127870347, 11.644357976653698),
#  ('liqueur', ('yogurt',), 0.00019295075127870347, 11.644357976653698),
#  ('make up remover', ('yogurt',), 0.00019295075127870347, 11.644357976653698),
#  ('organic products', ('yogurt',), 0.00019295075127870347, 11.644357976653698),
#  ('preservation products',
#   ('yogurt',),
#   0.00019295075127870347,
#   11.644357976653698),
#  ('rubbing alcohol', ('yogurt',), 0.00019295075127870347, 11.644357976653698),
#  ('salad dressing', ('yogurt',), 0.00019295075127870347, 11.644357976653698),
#  ('specialty vegetables',
#   ('yogurt',),
#   0.00019295075127870347,
#   11.644357976653698),
#  ('toilet cleaner', ('yogurt',), 0.00019295075127870347, 11.644357976653698),
#  ('whisky', ('yogurt',), 0.00019295075127870347, 11.644357976653698),
#  ('cooking chocolate', ('yogurt',), 0.00019295075127870347, 11.61563522697795),
#  ('ready soups', ('yogurt',), 0.00019295075127870347, 11.61563522697795),
#  ('pip fruit',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   0.0001097855813305425,
#   20.385558583106267),
#  ('ice cream',
#   ('yogurt', 'semi-finished bread'),
#   3.392308647450827e-05,
#   65.91629955947137),
#  ('soda',
#   ('yogurt', 'semi-finished bread'),
#   0.00021575854109722196,
#   10.298004129387476),
#  ('beef',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   29.45472440944882),
#  ('beef',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   29.45472440944882),
#  ('beef',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   29.45472440944882),
#  ('fruit/vegetable juice',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   29.396856581532415),
#  ('fruit/vegetable juice',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   29.396856581532415),
#  ('fruit/vegetable juice',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   7.466916606585943e-05,
#   29.396856581532415),
#  ('chocolate',
#   ('sausage', 'yogurt', 'whole milk'),
#   7.466916606585943e-05,
#   28.829689544166882),
#  ('cream cheese ',
#   ('sausage', 'yogurt', 'whole milk'),
#   7.466916606585943e-05,
#   28.74824974319466),
#  ('baby cosmetics',
#   ('semi-finished bread',),
#   2.0331845713966477e-05,
#   105.37323943661971),
#  ('bags',
#   ('semi-finished bread',),
#   2.0331845713966477e-05,
#   105.37323943661971),
#  ('cream',
#   ('semi-finished bread',),
#   2.0331845713966477e-05,
#   105.37323943661971),
#  ('decalcifier',
#   ('semi-finished bread',),
#   2.0331845713966477e-05,
#   105.37323943661971),
#  ('frozen chicken',
#   ('semi-finished bread',),
#   2.0331845713966477e-05,
#   105.37323943661971),
#  ('frozen fruits',
#   ('semi-finished bread',),
#   2.0331845713966477e-05,
#   105.37323943661971),
#  ('hair spray',
#   ('semi-finished bread',),
#   2.0331845713966477e-05,
#   105.37323943661971),
#  ('honey',
#   ('semi-finished bread',),
#   2.0331845713966477e-05,
#   105.37323943661971),
#  ('kitchen utensil',
#   ('semi-finished bread',),
#   2.0331845713966477e-05,
#   105.37323943661971),
#  ('liqueur',
#   ('semi-finished bread',),
#   2.0331845713966477e-05,
#   105.37323943661971),
#  ('make up remover',
#   ('semi-finished bread',),
#   2.0331845713966477e-05,
#   105.37323943661971),
#  ('organic products',
#   ('semi-finished bread',),
#   2.0331845713966477e-05,
#   105.37323943661971),
#  ('preservation products',
#   ('semi-finished bread',),
# ...
#  ('tropical fruit',
#   ('yogurt', 'whole milk'),
#   0.00018342842566755076,
#   1.3221566866267467),
#  ('pickled vegetables',
#   ('semi-finished bread',),
#   2.0331845713966477e-05,
#   11.766416281269708),
#  ('dishes',
#   ('semi-finished bread',),
#   2.0331845713966477e-05,
#   11.67925764214919),
#  ('specialty chocolate',
#   ('sausage', 'whole milk'),
#   3.392308647450827e-05,
#   6.990925154561918),
#  ('root vegetables',
#   ('yogurt', 'whole milk'),
#   0.00018342842566755076,
#   1.2878644382704332),
#  ('dessert',
#   ('sausage', 'whole milk'),
#   4.987688982417843e-05,
#   4.733232611728891),
#  ('pastry',
#   ('sausage', 'whole milk'),
#   0.00010882230507093476,
#   2.158696527054649),
#  ('specialty bar', ('yogurt',), 0.00023211344803960855, 1.002863366410366),
#  ('ham', ('sausage', 'whole milk'), 3.552094971647287e-05, 6.52668403101679),
#  ('citrus fruit',
#   ('sausage', 'whole milk'),
#   0.00010992852402812475,
#   2.101674354641885),
#  ('herbs',
#   ('semi-finished bread',),
#   2.3099737829140555e-05,
#   9.979112542342662),
#  ('flour', ('yogurt',), 0.00019295075127870347, 1.193387180853899),
#  ('salty snack',
#   ('sausage', 'whole milk'),
#   3.8541233045956064e-05,
#   5.946018191958358),
#  ('processed cheese', ('yogurt',), 0.00019295075127870347, 1.146279792135982),
#  ('flour',
#   ('semi-finished bread',),
#   2.0331845713966477e-05,
#   10.799313573220141),
#  ('red/blush wine', ('yogurt',), 0.00019295075127870347, 1.1097740662717785),
#  ('processed cheese',
#   ('semi-finished bread',),
#   2.0331845713966477e-05,
#   10.3730248795404),
#  ('red/blush wine',
#   ('semi-finished bread',),
#   2.0331845713966477e-05,
#   10.04267376872701),
#  ('hard cheese',
#   ('semi-finished bread',),
#   2.581735404433356e-05,
#   7.166817189500639),
#  ('specialty bar',
#   ('semi-finished bread',),
#   2.445854593673706e-05,
#   7.544018094211199),
#  ('beverages',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   2.7963104879318682e-06,
#   60.33467741935484),
#  ('curd',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   5.34946354213053e-06,
#   29.688492063492067),
#  ('white wine',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   1.8191823404749803e-06,
#   85.50285714285714),
#  ('cat food',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   1.8191823404749803e-06,
#   84.53672316384181),
#  ('sliced cheese',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   2.0668381867322503e-06,
#   71.25238095238095),
#  ('frozen meals',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   2.309995620465456e-06,
#   59.61354581673307),
#  ('grapes',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   1.945259469865648e-06,
#   69.27314814814814),
#  ('frozen vegetables',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   3.7689402228646923e-06,
#   35.71121718377088),
#  ('bottled beer',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   6.078935843330148e-06,
#   22.0693215339233),
#  ('hygiene articles',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   1.8191823404749803e-06,
#   72.99024390243903),
#  ('candy',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   1.8191823404749803e-06,
#   69.5953488372093),
#  ('misc. beverages',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   1.945259469865648e-06,
#   63.40254237288135),
#  ('oil',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   1.8191823404749803e-06,
#   67.09865470852017),
#  ('ice cream',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   1.8191823404749803e-06,
#   65.91629955947137),
#  ('beverages',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   1.9018724468602066e-06,
#   60.33467741935484),
#  ('beverages',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   1.9018724468602066e-06,
#   60.33467741935484),
#  ('beverages',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   1.9018724468602066e-06,
#   60.33467741935484),
#  ('specialty chocolate',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   1.8191823404749803e-06,
#   62.60669456066946),
#  ('dessert',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   2.674731771065265e-06,
#   42.388101983002834),
#  ('pastry',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   5.835778409596941e-06,
#   19.332041343669253),
#  ('ham',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   1.9048704335811436e-06,
#   58.44921875),
#  ('citrus fruit',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   5.89510125432485e-06,
#   18.82138364779874),
#  ('salty snack',
#   ('sausage', 'yogurt', 'semi-finished bread'),
#   2.0668381867322503e-06,
#   53.2491103202847),
#  ('curd',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   3.63836468094996e-06,
#   29.688492063492067),
#  ('curd',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   3.63836468094996e-06,
#   29.688492063492067),
#  ('curd',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   3.63836468094996e-06,
#   29.688492063492067),
#  ('white wine',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   1.2372920618421423e-06,
#   85.50285714285714),
#  ('white wine',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   1.2372920618421423e-06,
#   85.50285714285714),
#  ('white wine',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   1.2372920618421423e-06,
#   85.50285714285714),
#  ('cat food',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   1.2372920618421423e-06,
#   84.53672316384181),
#  ('cat food',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   1.2372920618421423e-06,
#   84.53672316384181),
#  ('cat food',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   1.2372920618421423e-06,
#   84.53672316384181),
#  ('beverages',
#   ('semi-finished bread', 'whole milk'),
#   2.7963104879318682e-06,
#   36.11151112903226),
#  ('sliced cheese',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   1.4057318085488483e-06,
#   71.25238095238095),
#  ('sliced cheese',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   1.4057318085488483e-06,
#   71.25238095238095),
#  ('sliced cheese',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   1.4057318085488483e-06,
#   71.25238095238095),
#  ('curd',
#   ('semi-finished bread', 'whole milk'),
#   5.34946354213053e-06,
#   17.76915626984127),
#  ('condensed milk',
#   ('sausage', 'yogurt'),
#   3.5375047374195394e-06,
#   26.565183792121495),
#  ('frozen meals',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   1.5711120213193009e-06,
#   59.61354581673307),
#  ('frozen meals',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   1.5711120213193009e-06,
#   59.61354581673307),
#  ('frozen meals',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   1.5711120213193009e-06,
#   59.61354581673307),
#  ('white wine',
#   ('semi-finished bread', 'whole milk'),
#   1.8191823404749803e-06,
#   51.17517005714286),
#  ('spread cheese',
#   ('sausage', 'yogurt'),
#   3.5375047374195394e-06,
#   26.03388011627907),
#  ('cat food',
#   ('semi-finished bread', 'whole milk'),
#   1.8191823404749803e-06,
#   50.596919548022605),
#  ('grapes',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   1.3230417021636221e-06,
#   69.27314814814814),
#  ('grapes',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   1.3230417021636221e-06,
#   69.27314814814814),
#  ('grapes',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   1.3230417021636221e-06,
#   69.27314814814814),
#  ('frozen vegetables',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   2.563393297942018e-06,
#   35.71121718377088),
#  ('frozen vegetables',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   2.563393297942018e-06,
#   35.71121718377088),
#  ('frozen vegetables',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   2.563393297942018e-06,
#   35.71121718377088),
#  ('bottled beer',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   4.1345053192613184e-06,
#   22.0693215339233),
#  ('bottled beer',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   4.1345053192613184e-06,
#   22.0693215339233),
#  ('bottled beer',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   4.1345053192613184e-06,
#   22.0693215339233),
#  ('hygiene articles',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   1.2372920618421423e-06,
#   72.99024390243903),
#  ('hygiene articles',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   1.2372920618421423e-06,
#   72.99024390243903),
#  ('hygiene articles',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   1.2372920618421423e-06,
#   72.99024390243903),
#  ('frozen fish',
#   ('sausage', 'yogurt'),
#   3.5375047374195394e-06,
#   25.52341187870497),
#  ('liquor', ('sausage', 'yogurt'), 3.5375047374195394e-06, 25.27561176337774),
#  ('sliced cheese',
#   ('semi-finished bread', 'whole milk'),
#   2.0668381867322503e-06,
#   42.64597504761905),
#  ('seasonal products',
#   ('sausage', 'yogurt'),
#   3.5375047374195394e-06,
#   24.560264260640633),
#  ('candy',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   1.2372920618421423e-06,
#   69.5953488372093),
#  ('candy',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   1.2372920618421423e-06,
#   69.5953488372093),
#  ('candy',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   1.2372920618421423e-06,
#   69.5953488372093),
#  ('misc. beverages',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   1.3230417021636221e-06,
#   63.40254237288135),
#  ('misc. beverages',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   1.3230417021636221e-06,
#   63.40254237288135),
#  ('misc. beverages',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   1.3230417021636221e-06,
#   63.40254237288135),
#  ('oil',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   1.2372920618421423e-06,
#   67.09865470852017),
#  ('oil',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   1.2372920618421423e-06,
#   67.09865470852017),
#  ('oil',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   1.2372920618421423e-06,
#   67.09865470852017),
#  ('frozen meals',
#   ('semi-finished bread', 'whole milk'),
#   2.309995620465456e-06,
#   35.679899442231076),
#  ('ice cream',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   1.2372920618421423e-06,
#   65.91629955947137),
#  ('ice cream',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   1.2372920618421423e-06,
#   65.91629955947137),
#  ('ice cream',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   1.2372920618421423e-06,
#   65.91629955947137),
#  ('grapes',
#   ('semi-finished bread', 'whole milk'),
#   1.945259469865648e-06,
#   41.461364629629635),
#  ('frozen vegetables',
#   ('semi-finished bread', 'whole milk'),
#   3.7689402228646923e-06,
#   21.37387770883055),
#  ('bottled beer',
#   ('semi-finished bread', 'whole milk'),
#   6.078935843330148e-06,
#   13.208930324483775),
#  ('canned fish',
#   ('sausage', 'yogurt'),
#   3.5375047374195394e-06,
#   22.638156622851366),
#  ('hygiene articles',
#   ('semi-finished bread', 'whole milk'),
#   1.8191823404749803e-06,
#   43.686120780487805),
#  ('pot plants',
#   ('sausage', 'yogurt'),
#   3.5375047374195394e-06,
#   22.251179586563303),
#  ('beverages',
#   ('sausage', 'yogurt', 'whole milk'),
#   1.9018724468602066e-06,
#   41.035808101173025),
#  ('soft cheese',
#   ('sausage', 'yogurt'),
#   4.491919401922827e-06,
#   17.35592007751938),
#  ('specialty chocolate',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   1.2372920618421423e-06,
#   62.60669456066946),
#  ('specialty chocolate',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   1.2372920618421423e-06,
#   62.60669456066946),
#  ('specialty chocolate',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   1.2372920618421423e-06,
#   62.60669456066946),
#  ('dessert',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   1.81918234047498e-06,
#   42.388101983002834),
#  ('dessert',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   1.81918234047498e-06,
#   42.388101983002834),
#  ('dessert',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   1.81918234047498e-06,
#   42.388101983002834),
#  ('pastry',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   3.969125106490865e-06,
#   19.332041343669253),
#  ('pastry',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   3.969125106490865e-06,
#   19.332041343669253),
#  ('pastry',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   3.969125106490865e-06,
#   19.332041343669253),
#  ('baking powder',
#   ('sausage', 'yogurt'),
#   3.5375047374195394e-06,
#   21.515603401883528),
#  ('pasta', ('sausage', 'yogurt'), 3.5375047374195394e-06, 21.515603401883528),
#  ('candy',
#   ('semi-finished bread', 'whole milk'),
#   1.8191823404749803e-06,
#   41.65420818604651),
#  ('ham',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   1.2955716498943024e-06,
#   58.44921875),
#  ('ham',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   1.2955716498943024e-06,
#   58.44921875),
#  ('ham',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   1.2955716498943024e-06,
#   58.44921875),
#  ('citrus fruit',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   4.009472730384669e-06,
#   18.82138364779874),
#  ('citrus fruit',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   4.009472730384669e-06,
#   18.82138364779874),
#  ('citrus fruit',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   4.009472730384669e-06,
#   18.82138364779874),
#  ('salty snack',
#   ('sausage', 'semi-finished bread', 'whole milk'),
#   1.4057318085488483e-06,
#   53.2491103202847),
#  ('salty snack',
#   ('yogurt', 'semi-finished bread', 'whole milk'),
#   1.4057318085488483e-06,
#   53.2491103202847),
#  ('salty snack',
#   ('sausage', 'yogurt', 'semi-finished bread', 'whole milk'),
#   1.4057318085488483e-06,
#   53.2491103202847),
#  ('misc. beverages',
#   ('semi-finished bread', 'whole milk'),
#   1.945259469865648e-06,
#   37.947689661016945),
#  ('curd',
#   ('sausage', 'yogurt', 'whole milk'),
#   3.63836468094996e-06,
#   20.192223033910537),
#  ('oil',
#   ('semi-finished bread', 'whole milk'),
#   1.8191823404749803e-06,
#   40.1598868161435),
#  ('packaged fruit/vegetables',
#   ('sausage', 'yogurt'),
#   3.5375047374195394e-06,
#   20.499118201794545),
#  ('white wine',
#   ('sausage', 'yogurt', 'whole milk'),
#   1.2372920618421423e-06,
#   58.153602337662335),
#  ('chewing gum',
#   ('sausage', 'yogurt'),
#   4.964753023177861e-06,
#   14.46326673126615),
#  ('ice cream',
#   ('semi-finished bread', 'whole milk'),
#   1.8191823404749803e-06,
#   39.452223612334805),
#  ('cat food',
#   ('sausage', 'yogurt', 'whole milk'),
#   1.2372920618421423e-06,
#   57.49649948638932),
#  ('pickled vegetables',
#   ('sausage', 'yogurt'),
#   3.5375047374195394e-06,
#   19.428268743491845),
#  ('dishes', ('sausage', 'yogurt'), 3.5375047374195394e-06, 19.2843556416882),
#  ('specialty chocolate',
#   ('semi-finished bread', 'whole milk'),
#   1.8191823404749803e-06,
#   37.47135882845188),
#  ('sliced cheese',
#   ('sausage', 'yogurt', 'whole milk'),
#   1.4057318085488483e-06,
#   48.46133528138528),
#  ('dessert',
#   ('semi-finished bread', 'whole milk'),
#   2.674731771065265e-06,
#   25.370126798866856),
#  ('pastry',
#   ('semi-finished bread', 'whole milk'),
#   5.835778409596941e-06,
#   11.570613385012921),
#  ('ham',
#   ('semi-finished bread', 'whole milk'),
#   1.9048704335811436e-06,
#   34.98302640625),
#  ('citrus fruit',
#   ('semi-finished bread', 'whole milk'),
#   5.89510125432485e-06,
#   11.264974540880502),
#  ('herbs', ('sausage', 'yogurt'), 4.019085780667792e-06, 16.477139314100675),
#  ('salty snack',
#   ('semi-finished bread', 'whole milk'),
#   2.0668381867322503e-06,
#   31.870657508896798),
#  ('frozen meals',
#   ('sausage', 'yogurt', 'whole milk'),
#   1.5711120213193009e-06,
#   40.54534027526259),
#  ('flour', ('sausage', 'yogurt'), 3.5375047374195394e-06, 17.831424737177443),
#  ('grapes',
#   ('sausage', 'yogurt', 'whole milk'),
#   1.3230417021636221e-06,
#   47.11518707912458),
#  ('frozen vegetables',
#   ('sausage', 'yogurt', 'whole milk'),
#   2.563393297942018e-06,
#   24.288497396398352),
#  ('bottled beer',
#   ('sausage', 'yogurt', 'whole milk'),
#   4.1345053192613184e-06,
#   15.01014809600429),
#  ('hygiene articles',
#   ('sausage', 'yogurt', 'whole milk'),
#   1.2372920618421423e-06,
#   49.64331906873614),
#  ('processed cheese',
#   ('sausage', 'yogurt'),
#   3.5375047374195394e-06,
#   17.127552708078337),
#  ('condensed milk',
#   ('yogurt', 'semi-finished bread'),
#   3.950125625821535e-07,
#   152.68367346938774),
#  ('spread cheese',
#   ('yogurt', 'semi-finished bread'),
#   3.950125625821535e-07,
#   149.63),
#  ...]

# %%
print(baskets[33])
generate_basic_candidates(baskets[33], products, supports)
generate_advanced_candidates(baskets[33], products, supports)
# Out:
# {'soda', 'domestic eggs', 'white wine', 'yogurt', 'root vegetables', 'tropical fruit', 'photo/film'}
# [('rolls/buns', ('soda', 'white wine'), 0.07458073584277149, 9.09052247873633),
#  ('other vegetables',
#   ('soda', 'white wine'),
#   0.07458073584277149,
#   8.189928845101258),
#  ('whole milk',
#   ('soda', 'white wine'),
#   0.07458073584277149,
#   6.332204824375794),
#  ('rolls/buns', ('photo/film',), 0.18940506329113924, 1.7217909854345788),
#  ('other vegetables',
#   ('photo/film',),
#   0.18940506329113924,
#   1.5512139912563307),
#  ('rolls/buns',
#   ('soda', 'domestic eggs'),
#   0.07458073584277149,
#   3.579512838140309),
#  ('chicken', ('white wine',), 0.08550285714285714, 3.0680557588215147),
#  ('frozen vegetables',
#   ('white wine',),
#   0.08550285714285714,
#   3.053411101261507),
#  ('other vegetables',
#   ('soda', 'domestic eggs'),
#   0.07458073584277149,
#   3.224892244980267),
#  ('chicken', ('soda', 'white wine'), 0.006376866002373656, 35.882494004796165),
#  ('whole milk', ('photo/film',), 0.18940506329113924, 1.1993516555333545),
#  ('margarine', ('white wine',), 0.08550285714285714, 2.654313799644339),
#  ('curd', ('white wine',), 0.08550285714285714, 2.5384508956916103),
#  ('beef', ('white wine',), 0.08550285714285714, 2.5184630933633296),
#  ('fruit/vegetable juice',
#   ('white wine',),
#   0.08550285714285714,
#   2.5135152287398266),
#  ('butter', ('white wine',), 0.08550285714285714, 2.427664613716454),
#  ('margarine',
#   ('soda', 'white wine'),
#   0.006376866002373656,
#   31.04356846473029),
#  ('pork', ('white wine',), 0.08550285714285714, 2.3051878404118407),
#  ('brown bread', ('white wine',), 0.08550285714285714, 2.272432062928191),
#  ('curd', ('soda', 'white wine'), 0.006376866002373656, 29.688492063492067),
#  ('beef', ('soda', 'white wine'), 0.006376866002373656, 29.45472440944882),
#  ('fruit/vegetable juice',
#   ('soda', 'white wine'),
#   0.006376866002373656,
#   29.396856581532415),
#  ('whole milk',
#   ('soda', 'domestic eggs'),
#   0.07458073584277149,
#   2.4933889680825003),
#  ('butter', ('soda', 'white wine'), 0.006376866002373656, 28.39278937381404),
#  ('pork', ('soda', 'white wine'), 0.006376866002373656, 26.960360360360358),
#  ('brown bread',
#   ('soda', 'white wine'),
#   0.006376866002373656,
#   26.57726465364121),
#  ('whipped/sour cream',
#   ('white wine',),
#   0.08550285714285714,
#   1.956237387505461),
#  ('bottled beer', ('white wine',), 0.08550285714285714, 1.886990046354825),
#  ('canned beer', ('white wine',), 0.08550285714285714, 1.8224775661375663),
#  ('shopping bags', ('white wine',), 0.08550285714285714, 1.7968809711075444),
#  ('pip fruit', ('white wine',), 0.08550285714285714, 1.7430235033086805),
#  ('whipped/sour cream',
#   ('soda', 'white wine'),
#   0.006376866002373656,
#   22.87920489296636),
#  ('pastry', ('white wine',), 0.08550285714285714, 1.65294476928756),
#  ('bottled beer',
#   ('soda', 'white wine'),
#   0.006376866002373656,
#   22.0693215339233),
#  ('citrus fruit', ('white wine',), 0.08550285714285714, 1.6092820772686434),
#  ('canned beer',
#   ('soda', 'white wine'),
#   0.006376866002373656,
#   21.314814814814813),
#  ('pip fruit',
#   ('soda', 'white wine'),
#   0.006376866002373656,
#   20.385558583106267),
#  ('pastry', ('soda', 'white wine'), 0.006376866002373656, 19.332041343669253),
#  ('bottled water', ('white wine',), 0.08550285714285714, 1.4090079861548144),
#  ('chicken', ('photo/film',), 0.016194674068716094, 6.796326048022342),
#  ('baby cosmetics', ('soda',), 0.010298004129387476, 10.298004129387476),
#  ('bags', ('soda',), 0.010298004129387476, 10.298004129387476),
#  ('cream', ('soda',), 0.010298004129387476, 10.298004129387476),
#  ('decalcifier', ('soda',), 0.010298004129387476, 10.298004129387476),
#  ('frozen chicken', ('soda',), 0.010298004129387476, 10.298004129387476),
#  ('frozen fruits', ('soda',), 0.010298004129387476, 10.298004129387476),
#  ('hair spray', ('soda',), 0.010298004129387476, 10.298004129387476),
#  ('honey', ('soda',), 0.010298004129387476, 10.298004129387476),
#  ('kitchen utensil', ('soda',), 0.010298004129387476, 10.298004129387476),
#  ('liqueur', ('soda',), 0.010298004129387476, 10.298004129387476),
#  ('make up remover', ('soda',), 0.010298004129387476, 10.298004129387476),
#  ('organic products', ('soda',), 0.010298004129387476, 10.298004129387476),
#  ('preservation products',
#   ('soda',),
#   0.010298004129387476,
#   10.298004129387476),
#  ('rubbing alcohol', ('soda',), 0.010298004129387476, 10.298004129387476),
#  ('salad dressing', ('soda',), 0.010298004129387476, 10.298004129387476),
#  ('specialty vegetables', ('soda',), 0.010298004129387476, 10.298004129387476),
#  ('toilet cleaner', ('soda',), 0.010298004129387476, 10.298004129387476),
#  ('whisky', ('soda',), 0.010298004129387476, 10.298004129387476),
#  ('cooking chocolate', ('soda',), 0.010298004129387476, 10.27260238586832),
#  ('ready soups', ('soda',), 0.010298004129387476, 10.27260238586832),
#  ('bottled water',
#   ('soda', 'white wine'),
#   0.006376866002373656,
#   16.479074889867842),
#  ('cocoa drinks', ('soda',), 0.010298004129387476, 9.630564736751548),
#  ('flower soil/fertilizer',
#   ('soda',),
#   0.010298004129387476,
#   9.630564736751548),
#  ('margarine', ('photo/film',), 0.016194674068716094, 5.879809049845055),
#  ('bathroom cleaner', ('soda',), 0.010298004129387476, 9.064060928707342),
#  ('cookware', ('soda',), 0.010298004129387476, 9.064060928707342),
#  ('pudding powder', ('soda',), 0.010298004129387476, 9.064060928707342),
#  ('curd', ('photo/film',), 0.016194674068716094, 5.623150718304199),
#  ('beef', ('photo/film',), 0.016194674068716094, 5.5788739409947175),
#  ('fruit/vegetable juice',
#   ('photo/film',),
#   0.016194674068716094,
#   5.567913481385691),
#  ('chicken',
#   ('soda', 'domestic eggs'),
#   0.006376866002373656,
#   14.129204152467501),
#  ('butter', ('photo/film',), 0.016194674068716094, 5.377738068359234),
#  ('prosecco', ('soda',), 0.010298004129387476, 8.109949252001305),
#  ('pork', ('photo/film',), 0.016194674068716094, 5.106428760405976),
#  ('brown bread', ('photo/film',), 0.016194674068716094, 5.033868493828272),
#  ('skin care', ('soda',), 0.010298004129387476, 7.704451789401239),
#  ('soap', ('soda',), 0.010298004129387476, 7.704451789401239),
#  ('margarine',
#   ('soda', 'domestic eggs'),
#   0.006376866002373656,
#   12.223813550993668),
#  ('canned fruit', ('soda',), 0.010298004129387476, 7.337573132763087),
#  ('syrup', ('soda',), 0.010298004129387476, 7.337573132763087),
#  ('curd', ('soda', 'domestic eggs'), 0.006376866002373656, 11.690234388053469),
#  ('beef', ('soda', 'domestic eggs'), 0.006376866002373656, 11.598185298383758),
#  ('fruit/vegetable juice',
#   ('soda', 'domestic eggs'),
#   0.006376866002373656,
#   11.575399079722885),
#  ('abrasive cleaner', ('soda',), 0.010298004129387476, 7.004047081273855),
#  ('nut snack', ('soda',), 0.010298004129387476, 7.004047081273855),
#  ('organic sausage', ('soda',), 0.010298004129387476, 7.004047081273855),
#  ('tidbits', ('soda',), 0.010298004129387476, 7.004047081273855),
#  ('butter',
#   ('soda', 'domestic eggs'),
#   0.006376866002373656,
#   11.180034405273146),
#  ('whipped/sour cream',
#   ('photo/film',),
#   0.016194674068716094,
#   4.333437250803237),
#  ('red/blush wine',
#   ('domestic eggs',),
#   0.026960360360360362,
#   2.569476892178803),
#  ('potato products', ('soda',), 0.010298004129387476, 6.699523295131511),
#  ('herbs', ('domestic eggs',), 0.026960360360360362, 2.553214380202988),
#  ('pork', ('soda', 'domestic eggs'), 0.006376866002373656, 10.615996633475582),
#  ('bottled beer', ('photo/film',), 0.016194674068716094, 4.180041241925245),
#  ('brown bread',
#   ('soda', 'domestic eggs'),
#   0.006376866002373656,
#   10.465147658221932),
#  ('canned beer', ('photo/film',), 0.016194674068716094, 4.037133849038913),
#  ('pip fruit', ('photo/film',), 0.016194674068716094, 3.861128013658469),
#  ('sausage', ('soda',), 0.06125258086717137, 1.0149749363405152),
#  ('cat food', ('domestic eggs',), 0.026960360360360362, 2.2791405201811985),
#  ('chewing gum', ('domestic eggs',), 0.026960360360360362, 2.241154844844845),
#  ('pastry', ('photo/film',), 0.016194674068716094, 3.6615865142445947),
#  ('snack products', ('soda',), 0.010298004129387476, 5.7070013254824),
#  ('tea', ('soda',), 0.010298004129387476, 5.7070013254824),
#  ('whipped/sour cream',
#   ('soda', 'domestic eggs'),
#   0.006376866002373656,
#   9.00898796877515),
#  ('bottled beer',
#   ('soda', 'domestic eggs'),
#   0.006376866002373656,
#   8.690085739791957),
#  ('artif. sweetener', ('soda',), 0.010298004129387476, 5.313415027173268),
#  ('fish', ('soda',), 0.010298004129387476, 5.313415027173268),
#  ('light bulbs', ('soda',), 0.010298004129387476, 5.313415027173268),
#  ('specialty fat', ('soda',), 0.010298004129387476, 5.313415027173268),
#  ('canned beer',
#   ('soda', 'domestic eggs'),
#   0.006376866002373656,
#   8.392988791423003),
#  ('hygiene articles',
#   ('domestic eggs',),
#   0.026960360360360362,
#   1.967843278400352),
#  ('kitchen towels', ('soda',), 0.010298004129387476, 5.13630119293416),
#  ('specialty bar',
#   ('domestic eggs',),
#   0.026960360360360362,
#   1.9301812060864691),
#  ('sliced cheese',
#   ('domestic eggs',),
#   0.026960360360360362,
#   1.920989867009867),
#  ('pip fruit',
#   ('soda', 'domestic eggs'),
#   0.006376866002373656,
#   8.02708192313208),
#  ('cleaner', ('soda',), 0.010298004129387476, 4.970614057678219),
#  ('candy', ('domestic eggs',), 0.026960360360360362, 1.8763156840561492),
#  ('bottled water', ('photo/film',), 0.016194674068716094, 3.1212202224948418),
#  ('ketchup', ('soda',), 0.010298004129387476, 4.815282368375774),
#  ('rum', ('soda',), 0.010298004129387476, 4.815282368375774),
#  ('hard cheese', ('domestic eggs',), 0.026960360360360362, 1.8336721457821459),
#  ('pastry',
#   ('soda', 'domestic eggs'),
#   0.006376866002373656,
#   7.612245648034817),
#  ('dental care', ('soda',), 0.010298004129387476, 4.669364720849236),
#  ('nuts/prunes', ('soda',), 0.010298004129387476, 4.669364720849236),
#  ('ice cream', ('domestic eggs',), 0.026960360360360362, 1.777127189744811),
#  ('jam', ('soda',), 0.010298004129387476, 4.532030464353671),
#  ('misc. beverages',
#   ('domestic eggs',),
#   0.026960360360360362,
#   1.7093553901358989),
#  ('specialty chocolate',
#   ('domestic eggs',),
#   0.026960360360360362,
#   1.6878990463266614),
#  ('meat spreads', ('soda',), 0.010298004129387476, 4.402543879657851),
#  ('coffee', ('domestic eggs',), 0.03783783783783784, 1.1969716016227643),
#  ('newspapers', ('domestic eggs',), 0.04144144144144145, 1.0654437943097737),
#  ('frozen meals',
#   ('domestic eggs',),
#   0.026960360360360362,
#   1.6072026775779766),
#  ('meat', ('domestic eggs',), 0.026960360360360362, 1.6008248891748893),
#  ('male cosmetics', ('soda',), 0.010298004129387476, 4.1645685348114805),
#  ('ham', ('domestic eggs',), 0.026960360360360362, 1.5758120002815315),
#  ('brandy', ('soda',), 0.010298004129387476, 4.054974626000653),
#  ('bottled water',
#   ('soda', 'domestic eggs'),
#   0.006376866002373656,
#   6.488852567818224),
#  ('butter milk', ('domestic eggs',), 0.026960360360360362, 1.5338702360154832),
#  ('sugar', ('domestic eggs',), 0.026960360360360362, 1.5222938568757438),
#  ('long life bakery product',
#   ('domestic eggs',),
#   0.026960360360360362,
#   1.5052532540002692),
#  ('female sanitary products',
#   ('soda',),
#   0.010298004129387476,
#   3.8522258947006196),
#  ('spices', ('soda',), 0.010298004129387476, 3.8522258947006196),
#  ('waffles', ('domestic eggs',), 0.026960360360360362, 1.4563461085634373),
#  ('salty snack', ('domestic eggs',), 0.026960360360360362, 1.4356152031034595),
#  ('softener', ('soda',), 0.010298004129387476, 3.7582691655615807),
#  ('frankfurter', ('domestic eggs',), 0.03783783783783784, 1.0020664912700312),
#  ('cereals', ('soda',), 0.010298004129387476, 3.6687865663815433),
#  ('sauces', ('soda',), 0.010298004129387476, 3.5020235406369276),
#  ('onions', ('domestic eggs',), 0.026960360360360362, 1.331379115749413),
#  ('house keeping products',
#   ('soda',),
#   0.010298004129387476,
#   3.4242007952894395),
#  ('curd cheese', ('soda',), 0.010298004129387476, 3.3497616475657557),
#  ('sparkling wine', ('soda',), 0.010298004129387476, 3.3497616475657557),
#  ('uht-milk', ('domestic eggs',), 0.026960360360360362, 1.2606496002252254),
#  ('berries', ('domestic eggs',), 0.026960360360360362, 1.2374474603437795),
#  ('hamburger meat',
#   ('domestic eggs',),
#   0.026960360360360362,
#   1.2336632173457862),
#  ('popcorn', ('soda',), 0.010298004129387476, 3.2101882455838497),
#  ('soups', ('soda',), 0.010298004129387476, 3.2101882455838497),
#  ('napkins', ('domestic eggs',), 0.026960360360360362, 1.2187549005198552),
#  ('rice', ('soda',), 0.010298004129387476, 3.144674199755608),
#  ('liver loaf', ('soda',), 0.010298004129387476, 3.0817807157604955),
#  ('vinegar', ('soda',), 0.010298004129387476, 3.021353642902447),
#  ('chocolate', ('domestic eggs',), 0.026960360360360362, 1.142798504453462),
#  ('dessert', ('domestic eggs',), 0.026960360360360362, 1.142798504453462),
#  ('cream cheese ',
#   ('domestic eggs',),
#   0.026960360360360362,
#   1.1395702600905993),
#  ('white bread', ('domestic eggs',), 0.02702702702702703, 1.126477452382745),
#  ('instant coffee', ('soda',), 0.010298004129387476, 2.611678572678386),
#  ('chocolate marshmallow', ('soda',), 0.010298004129387476, 2.56815059646708),
#  ('instant food products', ('soda',), 0.010298004129387476, 2.56815059646708),
#  ('zwieback', ('soda',), 0.010298004129387476, 2.56815059646708),
#  ('finished products', ('soda',), 0.010298004129387476, 2.407641184187887),
#  ('candles', ('soda',), 0.010298004129387476, 2.334682360424618),
#  ('dog food', ('soda',), 0.010298004129387476, 2.299836355045146),
#  ('liquor (appetizer)', ('soda',), 0.010298004129387476, 2.299836355045146),
#  ('sweet spreads', ('soda',), 0.010298004129387476, 2.2660152321768354),
#  ('oil', ('soda',), 0.01858224363386098, 1.246843549298035),
#  ('flower (seeds)', ('soda',), 0.010298004129387476, 2.2331744317105042),
#  ('beverages', ('soda',), 0.019270474879559536, 1.1626778855760054),
#  ('frozen potato products', ('soda',), 0.010298004129387476, 2.1401254970559),
#  ('specialty cheese', ('soda',), 0.010298004129387476, 2.1401254970559),
#  ('dish cleaner', ('soda',), 0.010298004129387476, 2.110808709424997),
#  ('cling film/bags', ('soda',), 0.010298004129387476, 2.0822842674057402),
#  ('mayonnaise', ('soda',), 0.010298004129387476, 2.054520477173664),
#  ('rolls/buns', ('soda', 'yogurt'), 0.012827029315119422, 1.5634653775785257),
#  ('turkey', ('soda',), 0.010298004129387476, 1.9261129473503098),
#  ('canned vegetables', ('soda',), 0.010298004129387476, 1.8791345827807904),
#  ('roll products ', ('soda',), 0.010298004129387476, 1.8791345827807904),
#  ('red/blush wine', ('white wine',), 0.0023051878404118406, 8.148912429481348),
#  ('pet care', ('soda',), 0.010298004129387476, 1.812812185741468),
#  ('herbs', ('white wine',), 0.0023051878404118406, 8.097337034358047),
#  ('other vegetables',
#   ('soda', 'yogurt'),
#   0.012827029315119422,
#   1.4085736242442544),
#  ('salt', ('soda',), 0.010298004129387476, 1.7313374807643234),
#  ('cake bar', ('soda',), 0.010298004129387476, 1.6748808237828778),
#  ('frozen dessert', ('soda',), 0.010298004129387476, 1.6748808237828778),
#  ('mustard', ('soda',), 0.010298004129387476, 1.6748808237828778),
#  ('cat food', ('white wine',), 0.0023051878404118406, 7.228131364003228),
#  ('chewing gum', ('white wine',), 0.0023051878404118406, 7.107662507936508),
#  ('condensed milk', ('soda',), 0.010298004129387476, 1.572337099877804),
#  ('spread cheese', ('soda',), 0.010298004129387476, 1.5408903578802478),
#  ('frozen fish', ('soda',), 0.010298004129387476, 1.5106768214512234),
#  ('liquor', ('soda',), 0.010298004129387476, 1.4960100561944156),
#  ('seasonal products', ('soda',), 0.010298004129387476, 1.4536701489436301),
#  ('grapes', ('soda',), 0.014452856159669649, 1.0011948459126712),
#  ('hygiene articles',
#   ('white wine',),
#   0.0023051878404118406,
#   6.240874397212544),
#  ('specialty bar', ('white wine',), 0.0023051878404118406, 6.121431825017088),
#  ('sliced cheese', ('white wine',), 0.0023051878404118406, 6.092282149659864),
#  ('whole milk', ('soda', 'yogurt'), 0.012827029315119422, 1.089066445829138),
#  ('canned fish', ('soda',), 0.010298004129387476, 1.3399046590263024),
#  ('candy', ('white wine',), 0.0023051878404118406, 5.950601169435216),
#  ('pot plants', ('soda',), 0.010298004129387476, 1.3170003058805537),
#  ('hard cheese', ('white wine',), 0.0023051878404118406, 5.815360233766234),
#  ('baking powder', ('soda',), 0.010298004129387476, 1.2734631056861552),
#  ('pasta', ('soda',), 0.010298004129387476, 1.2734631056861552),
#  ('ice cream', ('white wine',), 0.0023051878404118406, 5.6360319446192575),
#  ('misc. beverages',
#   ('white wine',),
#   0.0023051878404118406,
#   5.421098523002421),
#  ('packaged fruit/vegetables',
#   ('soda',),
#   0.010298004129387476,
#   1.2132994943938962),
#  ('specialty chocolate',
#   ('white wine',),
#   0.0023051878404118406,
#   5.353051261207412),
#  ('detergent', ('soda',), 0.010298004129387476, 1.194488649519572),
#  ('pickled vegetables', ('soda',), 0.010298004129387476, 1.149918177522573),
#  ('dishes', ('soda',), 0.010298004129387476, 1.14140026509648),
#  ('frozen meals', ('white wine',), 0.0023051878404118406, 5.097128491747297),
#  ('meat', ('white wine',), 0.0023051878404118406, 5.076901791383221),
#  ('ham', ('white wine',), 0.0023051878404118406, 4.9975752008928565),
#  ('ice cream',
#   ('soda', 'white wine'),
#   0.00017192260539372438,
#   65.91629955947137),
#  ('butter milk', ('white wine',), 0.0023051878404118406, 4.864559891363389),
#  ('semi-finished bread', ('soda',), 0.010298004129387476, 1.085134054845245),
#  ('sugar', ('white wine',), 0.0023051878404118406, 4.82784623180593),
#  ('long life bakery product',
#   ('white wine',),
#   0.0023051878404118406,
#   4.773803176972281),
#  ('misc. beverages',
#   ('soda', 'white wine'),
#   0.00017192260539372438,
#   63.40254237288135),
#  ('flour', ('soda',), 0.010298004129387476, 1.0554043547124985),
#  ('waffles', ('white wine',), 0.0023051878404118406, 4.618697658586901),
#  ('soft cheese', ('soda',), 0.010298004129387476, 1.027260238586832),
#  ('salty snack', ('white wine',), 0.0023051878404118406, 4.5529510726995435),
#  ('processed cheese', ('soda',), 0.010298004129387476, 1.0137436565001632),
#  ('frozen meals',
#   ('soda', 'white wine'),
#   0.00017192260539372438,
#   59.61354581673307),
#  ('ham', ('soda', 'white wine'), 0.00017192260539372438, 58.44921875),
#  ('butter milk',
#   ('soda', 'white wine'),
#   0.00017192260539372438,
#   56.893536121673),
#  ('onions', ('white wine',), 0.0023051878404118406, 4.222373767090995),
#  ('sugar', ('soda', 'white wine'), 0.00017192260539372438, 56.46415094339622),
#  ('long life bakery product',
#   ('soda', 'white wine'),
#   0.00017192260539372438,
#   55.832089552238806),
#  ('uht-milk', ('white wine',), 0.0023051878404118406, 3.9980601607142856),
#  ('salty snack',
#   ('soda', 'white wine'),
#   0.00017192260539372438,
#   53.2491103202847),
#  ('berries', ('white wine',), 0.0023051878404118406, 3.9244762313759862),
#  ('hamburger meat', ('white wine',), 0.0023051878404118406, 3.912474775010922),
#  ('napkins', ('white wine',), 0.0023051878404118406, 3.8651941130772554),
#  ('coffee', ('white wine',), 0.0032352432432432433, 2.7048187133796437),
#  ('onions',
#   ('soda', 'white wine'),
#   0.00017192260539372438,
#   49.382838283828384),
#  ('chocolate', ('white wine',), 0.0023051878404118406, 3.624303828409551),
#  ('dessert', ('white wine',), 0.0023051878404118406, 3.624303828409551),
#  ('cream cheese ', ('white wine',), 0.0023051878404118406, 3.614065682001614),
#  ('white bread', ('white wine',), 0.002310888030888031, 3.563730505372065),
#  ('berries',
#   ('soda', 'white wine'),
#   0.00017192260539372438,
#   45.898773006134974),
#  ('hamburger meat',
#   ('soda', 'white wine'),
#   0.00017192260539372438,
#   45.75840978593272),
#  ('newspapers', ('white wine',), 0.003543361647361648, 2.1982461364752086),
#  ('napkins',
#   ('soda', 'white wine'),
#   0.00017192260539372438,
#   45.20543806646526),
#  ('coffee', ('soda', 'white wine'), 0.00024128682171143566, 31.63424947145877),
#  ('baby cosmetics',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   26.960360360360358),
#  ('bags', ('domestic eggs',), 0.0002776379023207654, 26.960360360360358),
#  ('cream', ('domestic eggs',), 0.0002776379023207654, 26.960360360360358),
#  ('decalcifier',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   26.960360360360358),
#  ('frozen chicken',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   26.960360360360358),
#  ('frozen fruits',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   26.960360360360358),
#  ('hair spray', ('domestic eggs',), 0.0002776379023207654, 26.960360360360358),
#  ('honey', ('domestic eggs',), 0.0002776379023207654, 26.960360360360358),
#  ('kitchen utensil',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   26.960360360360358),
#  ('liqueur', ('domestic eggs',), 0.0002776379023207654, 26.960360360360358),
#  ('make up remover',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   26.960360360360358),
#  ('organic products',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   26.960360360360358),
#  ('preservation products',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   26.960360360360358),
#  ('rubbing alcohol',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   26.960360360360358),
#  ('salad dressing',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   26.960360360360358),
#  ('specialty vegetables',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   26.960360360360358),
#  ('toilet cleaner',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   26.960360360360358),
#  ('whisky', ('domestic eggs',), 0.0002776379023207654, 26.960360360360358),
#  ('cooking chocolate',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   26.89385813813814),
#  ('ready soups', ('domestic eggs',), 0.0002776379023207654, 26.89385813813814),
#  ('sausage', ('white wine',), 0.005237270671517059, 1.41680980224648),
#  ('frankfurter', ('white wine',), 0.0032352432432432433, 2.2643880556257905),
#  ('chocolate',
#   ('soda', 'white wine'),
#   0.00017192260539372438,
#   42.388101983002834),
#  ('dessert',
#   ('soda', 'white wine'),
#   0.00017192260539372438,
#   42.388101983002834),
#  ('cream cheese ',
#   ('soda', 'white wine'),
#   0.00017192260539372438,
#   42.26836158192091),
#  ('white bread',
#   ('soda', 'white wine'),
#   0.00017234772979388257,
#   41.67966573816156),
#  ('frozen vegetables',
#   ('soda', 'white wine'),
#   0.00019602277817094816,
#   35.71121718377088),
#  ('cocoa drinks',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   25.212992004504503),
#  ('flower soil/fertilizer',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   25.212992004504503),
#  ('newspapers',
#   ('soda', 'white wine'),
#   0.00026426651901728665,
#   25.709621993127147),
#  ('chicken', ('soda', 'yogurt'), 0.0010967476550978966, 6.1713765263651155),
#  ('bathroom cleaner',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   23.72987482776895),
#  ('cookware', ('domestic eggs',), 0.0002776379023207654, 23.72987482776895),
#  ('pudding powder',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   23.72987482776895),
#  ('citrus fruit',
#   ('soda', 'white wine'),
#   0.0003424153728901029,
#   18.82138364779874),
#  ('shopping bags',
#   ('soda', 'white wine'),
#   0.00030628559089210646,
#   21.015449438202246),
#  ('frankfurter',
#   ('soda', 'white wine'),
#   0.00024128682171143566,
#   26.483185840707964),
#  ('prosecco', ('domestic eggs',), 0.0002776379023207654, 21.231993266951164),
#  ('margarine', ('soda', 'yogurt'), 0.0010967476550978966, 5.3391369533075785),
#  ('curd', ('soda', 'yogurt'), 0.0010967476550978966, 5.106079387885423),
#  ('skin care', ('domestic eggs',), 0.0002776379023207654, 20.170393603603607),
#  ('soap', ('domestic eggs',), 0.0002776379023207654, 20.170393603603607),
#  ('beef', ('soda', 'yogurt'), 0.0010967476550978966, 5.065874038374514),
#  ('fruit/vegetable juice',
#   ('soda', 'yogurt'),
#   0.0010967476550978966,
#   5.0559214371203405),
#  ('ice cream', ('photo/film',), 0.00043661424881116925, 12.484880889979367),
#  ('butter', ('soda', 'yogurt'), 0.0010967476550978966, 4.883233418395166),
#  ('canned fruit',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   19.209898670098674),
#  ('syrup', ('domestic eggs',), 0.0002776379023207654, 19.209898670098674),
#  ('misc. beverages',
#   ('photo/film',),
#   0.00043661424881116925,
#   12.00876255095473),
#  ('abrasive cleaner',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   18.33672145782146),
#  ('nut snack', ('domestic eggs',), 0.0002776379023207654, 18.33672145782146),
#  ('organic sausage',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   18.33672145782146),
#  ('tidbits', ('domestic eggs',), 0.0002776379023207654, 18.33672145782146),
#  ('pork', ('soda', 'yogurt'), 0.0010967476550978966, 4.636872092782438),
#  ('brown bread', ('soda', 'yogurt'), 0.0010967476550978966, 4.570984034625671),
#  ('frozen meals', ('photo/film',), 0.00043661424881116925, 11.291107418427556),
#  ('potato products',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   17.539472698785744),
#  ('ham', ('photo/film',), 0.00043661424881116925, 11.070577976661392),
#  ('butter milk', ('photo/film',), 0.00043661424881116925, 10.775923809982192),
#  ('sugar', ('photo/film',), 0.00043661424881116925, 10.6945960831144),
#  ('citrus fruit', ('yogurt',), 0.004591204002223457, 1.0106423904265471),
#  ('long life bakery product',
#   ('photo/film',),
#   0.00043661424881116925,
#   10.574880455318345),
#  ('ice cream',
#   ('soda', 'domestic eggs'),
#   0.00017192260539372438,
#   25.955410271272896),
#  ('salty snack', ('photo/film',), 0.00043661424881116925, 10.08565111041038),
#  ('whipped/sour cream',
#   ('soda', 'yogurt'),
#   0.0010967476550978966,
#   3.9349602622236284),
#  ('misc. beverages',
#   ('soda', 'domestic eggs'),
#   0.00017192260539372438,
#   24.965585303300625),
#  ('rolls/buns',
#   ('soda', 'root vegetables'),
#   0.0024295042992674926,
#   1.7217909854345788),
#  ('bottled beer',
#   ('soda', 'yogurt'),
#   0.0010967476550978966,
#   3.795669633472349),
#  ('snack products',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   14.941032298965634),
#  ('tea', ('domestic eggs',), 0.0002776379023207654, 14.941032298965634),
#  ('shopping bags',
#   ('root vegetables',),
#   0.004106765472759709,
#   1.0093875810856026),
#  ('onions', ('photo/film',), 0.00043661424881116925, 9.35335961064461),
#  ('rolls/buns',
#   ('soda', 'photo/film'),
#   0.000448798429999253,
#   9.09052247873633),
#  ('rolls/buns',
#   ('domestic eggs', 'white wine'),
#   0.000448798429999253,
#   9.09052247873633),
#  ('frozen meals',
#   ('soda', 'domestic eggs'),
#   0.00017192260539372438,
#   23.473618054099394),
#  ('canned beer',
#   ('soda', 'yogurt'),
#   0.0010967476550978966,
#   3.6659031502767134),
#  ('ham',
#   ('soda', 'domestic eggs'),
#   0.00017192260539372438,
#   23.015148951480263),
#  ('artif. sweetener',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   13.910616278347316),
#  ('fish', ('domestic eggs',), 0.0002776379023207654, 13.910616278347316),
#  ('light bulbs',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   13.910616278347316),
#  ('specialty fat',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   13.910616278347316),
#  ('butter milk',
#   ('soda', 'domestic eggs'),
#   0.00017192260539372438,
#   22.40257844706824),
#  ('pip fruit', ('soda', 'yogurt'), 0.0010967476550978966, 3.506081759528955),
#  ('sugar',
#   ('soda', 'domestic eggs'),
#   0.00017192260539372438,
#   22.233502383316782),
#  ('berries', ('photo/film',), 0.00043661424881116925, 8.693460006212627),
#  ('hamburger meat',
#   ('photo/film',),
#   0.00043661424881116925,
#   8.666874501606474),
#  ('long life bakery product',
#   ('soda', 'domestic eggs'),
#   0.00017192260539372438,
#   21.984619893951297),
#  ('other vegetables',
#   ('soda', 'root vegetables'),
#   0.0024295042992674926,
#   1.5512139912563307),
#  ('napkins', ('photo/film',), 0.00043661424881116925, 8.562138858082527),
#  ('kitchen towels',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   13.44692906906907),
#  ('other vegetables',
#   ('soda', 'photo/film'),
#   0.000448798429999253,
#   8.189928845101258),
#  ('other vegetables',
#   ('domestic eggs', 'white wine'),
#   0.000448798429999253,
#   8.189928845101258),
#  ('coffee', ('photo/film',), 0.0006127714512487171, 5.9916870233093364),
#  ('pastry', ('soda', 'yogurt'), 0.0010967476550978966, 3.324888903739345),
#  ('cleaner', ('domestic eggs',), 0.0002776379023207654, 13.01315716361523),
#  ('salty snack',
#   ('soda', 'domestic eggs'),
#   0.00017192260539372438,
#   20.967537834800527),
#  ('chocolate', ('photo/film',), 0.00043661424881116925, 8.028521138881917),
#  ('dessert', ('photo/film',), 0.00043661424881116925, 8.028521138881917),
#  ('ketchup', ('domestic eggs',), 0.0002776379023207654, 12.606496002252252),
#  ('rum', ('domestic eggs',), 0.0002776379023207654, 12.606496002252252),
#  ('cream cheese ', ('photo/film',), 0.00043661424881116925, 8.005841700636488),
#  ('white bread', ('photo/film',), 0.0004376938937490836, 7.894339727090018),
#  ('dental care',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   12.224480971880972),
#  ('nuts/prunes',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   12.224480971880972),
#  ('frozen vegetables',
#   ('photo/film',),
#   0.0004978189915455476,
#   6.763885350895743),
#  ('onions',
#   ('soda', 'domestic eggs'),
#   0.00017192260539372438,
#   19.445142348445373),
#  ('jam', ('domestic eggs',), 0.0002776379023207654, 11.864937413884475),
#  ('newspapers', ('photo/film',), 0.0006711306370819283, 4.869532580799513),
#  ('meat spreads',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   11.525939202059204),
#  ('bottled water',
#   ('soda', 'yogurt'),
#   0.0010967476550978966,
#   2.8342114664033624),
#  ('berries',
#   ('soda', 'domestic eggs'),
#   0.00017192260539372438,
#   18.073245802389412),
#  ('citrus fruit', ('photo/film',), 0.0008695972846236657, 3.564865361038134),
#  ('hamburger meat',
#   ('soda', 'domestic eggs'),
#   0.00017192260539372438,
#   18.0179759375503),
#  ('shopping bags', ('photo/film',), 0.000777842174289918, 3.9804325309344333),
#  ('frankfurter', ('photo/film',), 0.0006127714512487171, 5.016049490310295),
#  ('napkins',
#   ('soda', 'domestic eggs'),
#   0.00017192260539372438,
#   17.800236047066306),
#  ('male cosmetics',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   10.902915461407353),
#  ('coffee',
#   ('soda', 'domestic eggs'),
#   0.00024128682171143566,
#   12.456401969511516),
#  ('brandy', ('domestic eggs',), 0.0002776379023207654, 10.615996633475582),
#  ('whole milk',
#   ('soda', 'root vegetables'),
#   0.0024295042992674926,
#   1.1993516555333545),
#  ('frozen vegetables',
#   ('root vegetables',),
#   0.002628329902566214,
#   1.0977511526231203),
#  ('chocolate',
#   ('soda', 'domestic eggs'),
#   0.00017192260539372438,
#   16.690872893991354),
#  ('dessert',
#   ('soda', 'domestic eggs'),
#   0.00017192260539372438,
#   16.690872893991354),
#  ('cream cheese ',
#   ('soda', 'domestic eggs'),
#   0.00017192260539372438,
#   16.643723535533752),
#  ('whole milk',
#   ('soda', 'photo/film'),
#   0.000448798429999253,
#   6.332204824375794),
#  ('whole milk',
#   ('domestic eggs', 'white wine'),
#   0.000448798429999253,
#   6.332204824375794),
#  ('white bread',
#   ('soda', 'domestic eggs'),
#   0.00017234772979388257,
#   16.411916801055565),
#  ('female sanitary products',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   10.085196801801803),
#  ('spices', ('domestic eggs',), 0.0002776379023207654, 10.085196801801803),
#  ('frozen vegetables',
#   ('soda', 'domestic eggs'),
#   0.00019602277817094816,
#   14.061761650546414),
#  ('softener', ('domestic eggs',), 0.0002776379023207654, 9.839216392001758),
#  ('newspapers',
#   ('soda', 'domestic eggs'),
#   0.00026426651901728665,
#   10.123501944293725),
#  ('cereals', ('domestic eggs',), 0.0002776379023207654, 9.604949335049337),
#  ('sauces', ('domestic eggs',), 0.0002776379023207654, 9.16836072891073),
#  ('citrus fruit',
#   ('soda', 'domestic eggs'),
#   0.0003424153728901029,
#   7.411167461105594),
#  ('shopping bags',
#   ('soda', 'domestic eggs'),
#   0.00030628559089210646,
#   8.27510973536369),
#  ('frankfurter',
#   ('soda', 'domestic eggs'),
#   0.00024128682171143566,
#   10.42810288775035),
#  ('house keeping products',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   8.96461937937938),
#  ('curd cheese', ('domestic eggs',), 0.0002776379023207654, 8.769736349392872),
#  ('sparkling wine',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   8.769736349392872),
#  ('popcorn', ('domestic eggs',), 0.0002776379023207654, 8.40433066816817),
#  ('soups', ('domestic eggs',), 0.0002776379023207654, 8.40433066816817),
#  ('rice', ('domestic eggs',), 0.0002776379023207654, 8.232813715756572),
#  ('liver loaf', ('domestic eggs',), 0.0002776379023207654, 8.068157441441443),
#  ('vinegar', ('domestic eggs',), 0.0002776379023207654, 7.909958275922983),
#  ('baby cosmetics',
#   ('white wine',),
#   2.3738833899574934e-05,
#   85.50285714285714),
#  ('bags', ('white wine',), 2.3738833899574934e-05, 85.50285714285714),
#  ('cream', ('white wine',), 2.3738833899574934e-05, 85.50285714285714),
#  ('decalcifier', ('white wine',), 2.3738833899574934e-05, 85.50285714285714),
#  ('frozen chicken',
#   ('white wine',),
#   2.3738833899574934e-05,
#   85.50285714285714),
#  ('frozen fruits', ('white wine',), 2.3738833899574934e-05, 85.50285714285714),
#  ('hair spray', ('white wine',), 2.3738833899574934e-05, 85.50285714285714),
#  ('honey', ('white wine',), 2.3738833899574934e-05, 85.50285714285714),
#  ('kitchen utensil',
#   ('white wine',),
#   2.3738833899574934e-05,
#   85.50285714285714),
#  ('liqueur', ('white wine',), 2.3738833899574934e-05, 85.50285714285714),
#  ('make up remover',
#   ('white wine',),
#   2.3738833899574934e-05,
#   85.50285714285714),
#  ('organic products',
#   ('white wine',),
#   2.3738833899574934e-05,
#   85.50285714285714),
#  ('preservation products',
#   ('white wine',),
#   2.3738833899574934e-05,
#   85.50285714285714),
#  ('rubbing alcohol',
#   ('white wine',),
#   2.3738833899574934e-05,
#   85.50285714285714),
#  ('salad dressing',
#   ('white wine',),
#   2.3738833899574934e-05,
#   85.50285714285714),
#  ('specialty vegetables',
#   ('white wine',),
#   2.3738833899574934e-05,
#   85.50285714285714),
#  ('toilet cleaner',
#   ('white wine',),
#   2.3738833899574934e-05,
#   85.50285714285714),
#  ('whisky', ('white wine',), 2.3738833899574934e-05, 85.50285714285714),
#  ('cooking chocolate',
#   ('white wine',),
#   2.3738833899574934e-05,
#   85.2919500952381),
#  ('ready soups', ('white wine',), 2.3738833899574934e-05, 85.2919500952381),
#  ('instant coffee',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   6.8374215605435955),
#  ('cocoa drinks', ('white wine',), 2.3738833899574934e-05, 79.9612032142857),
#  ('flower soil/fertilizer',
#   ('white wine',),
#   2.3738833899574934e-05,
#   79.9612032142857),
#  ('chocolate marshmallow',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   6.723464534534535),
#  ('instant food products',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   6.723464534534535),
#  ('zwieback', ('domestic eggs',), 0.0002776379023207654, 6.723464534534535),
#  ('bathroom cleaner',
#   ('white wine',),
#   2.3738833899574934e-05,
#   75.25760302521009),
#  ('cookware', ('white wine',), 2.3738833899574934e-05, 75.25760302521009),
#  ('pudding powder',
#   ('white wine',),
#   2.3738833899574934e-05,
#   75.25760302521009),
#  ('finished products',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   6.303248001126126),
#  ('candles', ('domestic eggs',), 0.0002776379023207654, 6.112240485940486),
#  ('dog food', ('domestic eggs',), 0.0002776379023207654, 6.021013016001077),
#  ('liquor (appetizer)',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   6.021013016001077),
#  ('sweet spreads',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   5.932468706942237),
#  ('flower (seeds)',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   5.846490899595247),
#  ('prosecco', ('white wine',), 2.3738833899574934e-05, 67.33575007518797),
#  ('frozen potato products',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   5.6028871121121115),
#  ('specialty cheese',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   5.6028871121121115),
#  ('dish cleaner',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   5.526135233864001),
#  ('skin care', ('white wine',), 2.3738833899574934e-05, 63.96896257142857),
#  ('soap', ('white wine',), 2.3738833899574934e-05, 63.96896257142857),
#  ('cling film/bags',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   5.451457730703677),
#  ('mayonnaise', ('domestic eggs',), 0.0002776379023207654, 5.3787716276276285),
#  ('canned fruit', ('white wine',), 2.3738833899574934e-05, 60.922821496598644),
#  ('syrup', ('white wine',), 2.3738833899574934e-05, 60.922821496598644),
#  ('chicken',
#   ('soda', 'root vegetables'),
#   0.00020772955902822565,
#   6.796326048022342),
#  ('turkey', ('domestic eggs',), 0.0002776379023207654, 5.042598400900902),
#  ('abrasive cleaner',
#   ('white wine',),
#   2.3738833899574934e-05,
#   58.153602337662335),
#  ('nut snack', ('white wine',), 2.3738833899574934e-05, 58.153602337662335),
#  ('organic sausage',
#   ('white wine',),
#   2.3738833899574934e-05,
#   58.153602337662335),
#  ('tidbits', ('white wine',), 2.3738833899574934e-05, 58.153602337662335),
#  ('chicken', ('soda', 'photo/film'), 3.83735480461647e-05, 35.882494004796165),
#  ('chicken',
#   ('domestic eggs', 'white wine'),
#   3.83735480461647e-05,
#   35.882494004796165),
#  ('canned vegetables',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   4.919608196000879),
#  ('roll products ',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   4.919608196000879),
#  ('potato products',
#   ('white wine',),
#   2.3738833899574934e-05,
#   55.62518484472049),
#  ('pet care', ('domestic eggs',), 0.0002776379023207654, 4.745974965553789),
#  ('salt', ('domestic eggs',), 0.0002776379023207654, 4.532672719910923),
#  ('margarine',
#   ('soda', 'root vegetables'),
#   0.00020772955902822565,
#   5.879809049845055),
#  ('cake bar', ('domestic eggs',), 0.0002776379023207654, 4.384868174696436),
#  ('frozen dessert',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   4.384868174696436),
#  ('mustard', ('domestic eggs',), 0.0002776379023207654, 4.384868174696436),
#  ('margarine',
#   ('soda', 'photo/film'),
#   3.83735480461647e-05,
#   31.04356846473029),
#  ('margarine',
#   ('domestic eggs', 'white wine'),
#   3.83735480461647e-05,
#   31.04356846473029),
#  ('curd',
#   ('soda', 'root vegetables'),
#   0.00020772955902822565,
#   5.623150718304199),
#  ('beef',
#   ('soda', 'root vegetables'),
#   0.00020772955902822565,
#   5.5788739409947175),
#  ('fruit/vegetable juice',
#   ('soda', 'root vegetables'),
#   0.00020772955902822565,
#   5.567913481385691),
#  ('condensed milk',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   4.116406857878286),
#  ('curd', ('soda', 'photo/film'), 3.83735480461647e-05, 29.688492063492067),
#  ('curd',
#   ('domestic eggs', 'white wine'),
#   3.83735480461647e-05,
#   29.688492063492067),
#  ('beef', ('soda', 'photo/film'), 3.83735480461647e-05, 29.45472440944882),
#  ('beef',
#   ('domestic eggs', 'white wine'),
#   3.83735480461647e-05,
#   29.45472440944882),
#  ('fruit/vegetable juice',
#   ('soda', 'photo/film'),
#   3.83735480461647e-05,
#   29.396856581532415),
#  ('fruit/vegetable juice',
#   ('domestic eggs', 'white wine'),
#   3.83735480461647e-05,
#   29.396856581532415),
#  ('snack products',
#   ('white wine',),
#   2.3738833899574934e-05,
#   47.38441671957672),
#  ('tea', ('white wine',), 2.3738833899574934e-05, 47.38441671957672),
#  ('spread cheese',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   4.034078720720721),
#  ('butter',
#   ('soda', 'root vegetables'),
#   0.00020772955902822565,
#   5.377738068359234),
#  ('frozen fish',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   3.9549791379614914),
#  ('butter', ('soda', 'photo/film'), 3.83735480461647e-05, 28.39278937381404),
#  ('butter',
#   ('domestic eggs', 'white wine'),
#   3.83735480461647e-05,
#   28.39278937381404),
#  ('liquor', ('domestic eggs',), 0.0002776379023207654, 3.9165812822531274),
#  ('pork',
#   ('soda', 'root vegetables'),
#   0.00020772955902822565,
#   5.106428760405976),
#  ('seasonal products',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   3.805734642189359),
#  ('artif. sweetener',
#   ('white wine',),
#   2.3738833899574934e-05,
#   44.11652591133005),
#  ('fish', ('white wine',), 2.3738833899574934e-05, 44.11652591133005),
#  ('light bulbs', ('white wine',), 2.3738833899574934e-05, 44.11652591133005),
#  ('specialty fat', ('white wine',), 2.3738833899574934e-05, 44.11652591133005),
#  ('brown bread',
#   ('soda', 'root vegetables'),
#   0.00020772955902822565,
#   5.033868493828272),
#  ('pork', ('soda', 'photo/film'), 3.83735480461647e-05, 26.960360360360358),
#  ('pork',
#   ('domestic eggs', 'white wine'),
#   3.83735480461647e-05,
#   26.960360360360358),
#  ('brown bread',
#   ('soda', 'photo/film'),
#   3.83735480461647e-05,
#   26.57726465364121),
#  ('brown bread',
#   ('domestic eggs', 'white wine'),
#   3.83735480461647e-05,
#   26.57726465364121),
#  ('kitchen towels',
#   ('white wine',),
#   2.3738833899574934e-05,
#   42.64597504761905),
#  ('cleaner', ('white wine',), 2.3738833899574934e-05, 41.270298433179725),
#  ('canned fish',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   3.5078945397571486),
#  ('pot plants', ('domestic eggs',), 0.0002776379023207654, 3.4479305305305306),
#  ('rolls/buns',
#   ('domestic eggs', 'yogurt'),
#   0.00021662486800254268,
#   4.387789930623604),
#  ('ketchup', ('white wine',), 2.3738833899574934e-05, 39.98060160714285),
#  ('rum', ('white wine',), 2.3738833899574934e-05, 39.98060160714285),
#  ('baking powder',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   3.333949355967538),
#  ('pasta', ('domestic eggs',), 0.0002776379023207654, 3.333949355967538),
#  ('dental care', ('white wine',), 2.3738833899574934e-05, 38.76906822510823),
#  ('nuts/prunes', ('white wine',), 2.3738833899574934e-05, 38.76906822510823),
#  ('oil', ('domestic eggs',), 0.0005009839846729043, 1.8090039106370945),
#  ('whipped/sour cream',
#   ('soda', 'root vegetables'),
#   0.00020772955902822565,
#   4.333437250803237),
#  ('jam', ('white wine',), 2.3738833899574934e-05, 37.628801512605044),
#  ('packaged fruit/vegetables',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   3.176439937575371),
#  ('whipped/sour cream',
#   ('soda', 'photo/film'),
#   3.83735480461647e-05,
#   22.87920489296636),
#  ('whipped/sour cream',
#   ('domestic eggs', 'white wine'),
#   3.83735480461647e-05,
#   22.87920489296636),
#  ('bottled beer',
#   ('soda', 'root vegetables'),
#   0.00020772955902822565,
#   4.180041241925245),
#  ('detergent', ('domestic eggs',), 0.0002776379023207654, 3.127192806760249),
#  ('meat spreads', ('white wine',), 2.3738833899574934e-05, 36.55369289795919),
#  ('other vegetables',
#   ('domestic eggs', 'yogurt'),
#   0.00021662486800254268,
#   3.9530937196532308),
#  ('bottled beer',
#   ('soda', 'photo/film'),
#   3.83735480461647e-05,
#   22.0693215339233),
#  ('bottled beer',
#   ('domestic eggs', 'white wine'),
#   3.83735480461647e-05,
#   22.0693215339233),
#  ('beverages', ('domestic eggs',), 0.000519538947068197, 1.6266446454519037),
#  ('canned beer',
#   ('soda', 'root vegetables'),
#   0.00020772955902822565,
#   4.037133849038913),
#  ('pickled vegetables',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   3.0105065080005384),
#  ('dishes', ('domestic eggs',), 0.0002776379023207654, 2.9882064597931266),
#  ('male cosmetics',
#   ('white wine',),
#   2.3738833899574934e-05,
#   34.57781760617761),
#  ('canned beer',
#   ('soda', 'photo/film'),
#   3.83735480461647e-05,
#   21.314814814814813),
#  ('canned beer',
#   ('domestic eggs', 'white wine'),
#   3.83735480461647e-05,
#   21.314814814814813),
#  ('pip fruit',
#   ('soda', 'root vegetables'),
#   0.00020772955902822565,
#   3.861128013658469),
#  ('brandy', ('white wine',), 2.3738833899574934e-05, 33.66787503759399),
#  ('semi-finished bread',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   2.8409005075498035),
#  ('pip fruit',
#   ('soda', 'photo/film'),
#   3.83735480461647e-05,
#   20.385558583106267),
#  ('pip fruit',
#   ('domestic eggs', 'white wine'),
#   3.83735480461647e-05,
#   20.385558583106267),
#  ('flour', ('domestic eggs',), 0.0002776379023207654, 2.7630676169320005),
#  ('pastry',
#   ('soda', 'root vegetables'),
#   0.00020772955902822565,
#   3.6615865142445947),
#  ('female sanitary products',
#   ('white wine',),
#   2.3738833899574934e-05,
#   31.984481285714285),
#  ('spices', ('white wine',), 2.3738833899574934e-05, 31.984481285714285),
#  ('rolls/buns',
#   ('soda', 'tropical fruit'),
#   0.000448798429999253,
#   1.6792776277695274),
#  ('soft cheese',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   2.6893858138138143),
#  ('pastry', ('soda', 'photo/film'), 3.83735480461647e-05, 19.332041343669253),
#  ('pastry',
#   ('domestic eggs', 'white wine'),
#   3.83735480461647e-05,
#   19.332041343669253),
#  ('softener', ('white wine',), 2.3738833899574934e-05, 31.204371986062718),
#  ('processed cheese',
#   ('domestic eggs',),
#   0.0002776379023207654,
#   2.6539991583688956),
#  ('grapes', ('domestic eggs',), 0.0003896542103011477, 1.8676290373707043),
#  ('cereals', ('white wine',), 2.3738833899574934e-05, 30.461410748299322),
#  ('sauces', ('white wine',), 2.3738833899574934e-05, 29.076801168831167),
#  ('other vegetables',
#   ('soda', 'tropical fruit'),
#   0.000448798429999253,
#   1.5129124112253105),
#  ('house keeping products',
#   ('white wine',),
#   2.3738833899574934e-05,
#   28.430650031746033),
#  ('whole milk',
#   ('domestic eggs', 'yogurt'),
#   0.00021662486800254268,
#   3.056412283455968),
#  ('curd cheese', ('white wine',), 2.3738833899574934e-05, 27.812592422360247),
#  ('sparkling wine',
#   ('white wine',),
#   2.3738833899574934e-05,
#   27.812592422360247),
#  ('bottled water',
#   ('soda', 'root vegetables'),
#   0.00020772955902822565,
#   3.1212202224948418),
#  ('popcorn', ('white wine',), 2.3738833899574934e-05, 26.653734404761906),
#  ('soups', ('white wine',), 2.3738833899574934e-05, 26.653734404761906),
#  ('bottled water',
#   ('soda', 'photo/film'),
#   3.83735480461647e-05,
#   16.479074889867842),
#  ('bottled water',
#   ('domestic eggs', 'white wine'),
#   3.83735480461647e-05,
#   16.479074889867842),
#  ('rice', ('white wine',), 2.3738833899574934e-05, 26.109780641399414),
#  ('liver loaf', ('white wine',), 2.3738833899574934e-05, 25.58758502857143),
#  ('vinegar', ('white wine',), 2.3738833899574934e-05, 25.08586767507003),
#  ('whole milk',
#   ('soda', 'tropical fruit'),
#   0.000448798429999253,
#   1.1697380344090742),
#  ('instant coffee',
#   ('white wine',),
#   2.3738833899574934e-05,
#   21.684394092009683),
#  ('chocolate marshmallow',
#   ('white wine',),
#   2.3738833899574934e-05,
#   21.322987523809523),
#  ('instant food products',
#   ('white wine',),
#   2.3738833899574934e-05,
#   21.322987523809523),
#  ('zwieback', ('white wine',), 2.3738833899574934e-05, 21.322987523809523),
#  ('rolls/buns',
#   ('domestic eggs', 'root vegetables'),
#   0.00010804526333073488,
#   4.5340495949777235),
#  ('finished products',
#   ('white wine',),
#   2.3738833899574934e-05,
#   19.990300803571426),
#  ('candles', ('white wine',), 2.3738833899574934e-05, 19.384534112554114),
#  ('rolls/buns',
#   ('domestic eggs', 'photo/film'),
#   5.052128985055581e-05,
#   9.09052247873633),
#  ('rolls/buns',
#   ('white wine', 'yogurt'),
#   5.052128985055581e-05,
#   9.09052247873633),
#  ('rolls/buns',
#   ('white wine', 'root vegetables'),
#   5.052128985055581e-05,
#   9.09052247873633),
#  ('rolls/buns',
#   ('white wine', 'tropical fruit'),
#   5.052128985055581e-05,
#   9.09052247873633),
#  ('rolls/buns',
#   ('white wine', 'photo/film'),
#   5.052128985055581e-05,
#   9.09052247873633),
#  ('dog food', ('white wine',), 2.3738833899574934e-05, 19.095212707889125),
#  ('liquor (appetizer)',
#   ('white wine',),
#   2.3738833899574934e-05,
#   19.095212707889125),
#  ('sweet spreads',
#   ('white wine',),
#   2.3738833899574934e-05,
#   18.814400756302522),
#  ('other vegetables',
#   ('domestic eggs', 'root vegetables'),
#   0.00010804526333073488,
#   4.084863510308338),
#  ('flower (seeds)', ('white wine',), 2.3738833899574934e-05, 18.5417282815735),
#  ('sausage', ('soda', 'white wine'), 2.6141289526924285e-05, 16.5703211517165),
#  ('frozen potato products',
#   ('white wine',),
#   2.3738833899574934e-05,
#   17.769156269841268),
#  ('specialty cheese',
#   ('white wine',),
#   2.3738833899574934e-05,
#   17.769156269841268),
#  ('dish cleaner', ('white wine',), 2.3738833899574934e-05, 17.525743170254405),
#  ('other vegetables',
#   ('domestic eggs', 'photo/film'),
#   5.052128985055581e-05,
#   8.189928845101258),
#  ('other vegetables',
#   ('white wine', 'yogurt'),
#   5.052128985055581e-05,
#   8.189928845101258),
#  ('other vegetables',
#   ('white wine', 'root vegetables'),
#   5.052128985055581e-05,
#   8.189928845101258),
#  ('other vegetables',
#   ('white wine', 'tropical fruit'),
#   5.052128985055581e-05,
#   8.189928845101258),
#  ('other vegetables',
#   ('white wine', 'photo/film'),
#   5.052128985055581e-05,
#   8.189928845101258),
#  ('cling film/bags',
#   ('white wine',),
#   2.3738833899574934e-05,
#   17.288908803088805),
#  ('mayonnaise', ('white wine',), 2.3738833899574934e-05, 17.05839001904762),
#  ('sausage', ('yogurt',), 0.0003505099437746825, 1.1089864739670185),
# ...
#   4.319714628764952e-06,
#   10.319476816002949),
#  ('white bread',
#   ('soda', 'root vegetables'),
#   5.614312406168261e-06,
#   7.894339727090018),
#  ('chocolate',
#   ('soda', 'photo/film'),
#   1.0345646836302028e-06,
#   42.388101983002834),
#  ('dessert',
#   ('soda', 'photo/film'),
#   1.0345646836302028e-06,
#   42.388101983002834),
#  ('chocolate',
#   ('domestic eggs', 'white wine'),
#   1.0345646836302028e-06,
#   42.388101983002834),
#  ('dessert',
#   ('domestic eggs', 'white wine'),
#   1.0345646836302028e-06,
#   42.388101983002834),
#  ('cream cheese ',
#   ('soda', 'photo/film'),
#   1.0345646836302028e-06,
#   42.26836158192091),
#  ('cream cheese ',
#   ('domestic eggs', 'white wine'),
#   1.0345646836302028e-06,
#   42.26836158192091),
#  ('white bread',
#   ('soda', 'photo/film'),
#   1.0371229201666134e-06,
#   41.67966573816156),
#  ('white bread',
#   ('domestic eggs', 'white wine'),
#   1.0371229201666134e-06,
#   41.67966573816156),
#  ('frozen vegetables',
#   ('soda', 'root vegetables'),
#   6.385538798177927e-06,
#   6.763885350895743),
#  ('canned beer',
#   ('domestic eggs', 'tropical fruit'),
#   4.319714628764952e-06,
#   9.966674189814814),
#  ('frozen vegetables',
#   ('soda', 'photo/film'),
#   1.1795903337918065e-06,
#   35.71121718377088),
#  ('frozen vegetables',
#   ('domestic eggs', 'white wine'),
#   1.1795903337918065e-06,
#   35.71121718377088),
#  ('newspapers',
#   ('soda', 'root vegetables'),
#   8.608612356124668e-06,
#   4.869532580799513),
#  ('pip fruit',
#   ('domestic eggs', 'tropical fruit'),
#   4.319714628764952e-06,
#   9.532159783719345),
#  ('newspapers',
#   ('soda', 'photo/film'),
#   1.590255144255474e-06,
#   25.709621993127147),
#  ('newspapers',
#   ('domestic eggs', 'white wine'),
#   1.590255144255474e-06,
#   25.709621993127147),
#  ('cat food', ('root vegetables',), 3.3134030409301025e-05, 1.21510373554329),
#  ('citrus fruit',
#   ('soda', 'root vegetables'),
#   1.1154349862216008e-05,
#   3.564865361038134),
#  ('shopping bags',
#   ('soda', 'root vegetables'),
#   9.97740437215301e-06,
#   3.9804325309344333),
#  ('frankfurter',
#   ('soda', 'root vegetables'),
#   7.860037368635566e-06,
#   5.016049490310295),
#  ('pastry',
#   ('domestic eggs', 'tropical fruit'),
#   4.319714628764952e-06,
#   9.039541707041344),
#  ('citrus fruit',
#   ('soda', 'photo/film'),
#   2.0605251480041744e-06,
#   18.82138364779874),
#  ('citrus fruit',
#   ('domestic eggs', 'white wine'),
#   2.0605251480041744e-06,
#   18.82138364779874),
#  ('shopping bags',
#   ('soda', 'photo/film'),
#   1.8431098965496974e-06,
#   21.015449438202246),
#  ('shopping bags',
#   ('domestic eggs', 'white wine'),
#   1.8431098965496974e-06,
#   21.015449438202246),
#  ('frankfurter',
#   ('soda', 'photo/film'),
#   1.451972088233259e-06,
#   26.483185840707964),
#  ('frankfurter',
#   ('domestic eggs', 'white wine'),
#   1.451972088233259e-06,
#   26.483185840707964),
#  ('herbs', ('yogurt',), 3.0496648472374544e-05, 1.2528739595133724),
#  ('hygiene articles',
#   ('root vegetables',),
#   3.3215963118326234e-05,
#   1.0517326210726083),
#  ('hard cheese', ('yogurt',), 3.408448946912449e-05, 1.0056490979837283),
#  ('bottled water',
#   ('domestic eggs', 'tropical fruit'),
#   4.319714628764952e-06,
#   7.70551242428414),
#  ('candy', ('root vegetables',), 3.3134030409301025e-05, 1.0003412148426156),
#  ('specialty bar', ('yogurt',), 3.229056897074952e-05, 1.002863366410366),
#  ('red/blush wine', ('yogurt',), 2.6842432417184723e-05, 1.1097740662717785),
#  ('rolls/buns',
#   ('yogurt', 'root vegetables'),
#   1.1811719688029164e-05,
#   2.1253357476458077),
#  ('other vegetables',
#   ('yogurt', 'root vegetables'),
#   1.1811719688029164e-05,
#   1.9147797704570333),
#  ('rolls/buns',
#   ('yogurt', 'photo/film'),
#   2.2658815601535944e-06,
#   9.09052247873633),
#  ('other vegetables',
#   ('yogurt', 'photo/film'),
#   2.2658815601535944e-06,
#   8.189928845101258),
#  ('whole milk',
#   ('yogurt', 'root vegetables'),
#   1.1811719688029164e-05,
#   1.4804496997989844),
#  ('ice cream',
#   ('domestic eggs', 'yogurt'),
#   4.993610116502814e-07,
#   31.816309364786136),
#  ('misc. beverages',
#   ('domestic eggs', 'yogurt'),
#   4.993610116502814e-07,
#   30.602975533078183),
#  ('frozen meals',
#   ('domestic eggs', 'yogurt'),
#   4.993610116502814e-07,
#   28.77411245341216),
#  ('whole milk',
#   ('yogurt', 'photo/film'),
#   2.2658815601535944e-06,
#   6.332204824375794),
#  ('ham',
#   ('domestic eggs', 'yogurt'),
#   4.993610116502814e-07,
#   28.21211806955645),
#  ('butter milk',
#   ('domestic eggs', 'yogurt'),
#   4.993610116502814e-07,
#   27.461225193180425),
#  ('sugar',
#   ('domestic eggs', 'yogurt'),
#   4.993610116502814e-07,
#   27.25397066342057),
#  ('long life bakery product',
#   ('domestic eggs', 'yogurt'),
#   4.993610116502814e-07,
#   26.948888902262883),
#  ('salty snack',
#   ('domestic eggs', 'yogurt'),
#   4.993610116502814e-07,
#   25.70214315233613),
#  ('sausage', ('soda', 'yogurt'), 4.496001324038714e-06, 2.849904774633724),
#  ('ice cream',
#   ('soda', 'tropical fruit'),
#   1.0345646836302028e-06,
#   12.17661222602926),
#  ('misc. beverages',
#   ('soda', 'tropical fruit'),
#   1.0345646836302028e-06,
#   11.712249895375601),
#  ('onions',
#   ('domestic eggs', 'yogurt'),
#   4.993610116502814e-07,
#   23.835980943255617),
#  ('frozen meals',
#   ('soda', 'tropical fruit'),
#   1.0345646836302028e-06,
#   11.012314642663913),
#  ('ham',
#   ('soda', 'tropical fruit'),
#   1.0345646836302028e-06,
#   10.797230372299381),
#  ('berries',
#   ('domestic eggs', 'yogurt'),
#   4.993610116502814e-07,
#   22.154301306154764),
#  ('hamburger meat',
#   ('domestic eggs', 'yogurt'),
#   4.993610116502814e-07,
#   22.086551149255207),
#  ('napkins',
#   ('domestic eggs', 'yogurt'),
#   4.993610116502814e-07,
#   21.819644186726443),
#  ('butter milk',
#   ('soda', 'tropical fruit'),
#   1.0345646836302028e-06,
#   10.509851617143125),
#  ('sugar',
#   ('soda', 'tropical fruit'),
#   1.0345646836302028e-06,
#   10.430531982296761),
#  ('coffee',
#   ('domestic eggs', 'yogurt'),
#   7.008341405236856e-07,
#   15.269137898110891),
#  ('long life bakery product',
#   ('soda', 'tropical fruit'),
#   1.0345646836302028e-06,
#   10.31377229592777),
#  ('chocolate',
#   ('domestic eggs', 'yogurt'),
#   4.993610116502814e-07,
#   20.45977967650553),
#  ('dessert',
#   ('domestic eggs', 'yogurt'),
#   4.993610116502814e-07,
#   20.45977967650553),
#  ('cream cheese ',
#   ('domestic eggs', 'yogurt'),
#   4.993610116502814e-07,
#   20.401983688718794),
#  ('salty snack',
#   ('soda', 'tropical fruit'),
#   1.0345646836302028e-06,
#   9.836622687931111),
#  ('white bread',
#   ('domestic eggs', 'yogurt'),
#   5.005958146597754e-07,
#   20.117833498068112),
#  ('frozen vegetables',
#   ('domestic eggs', 'yogurt'),
#   5.69361618210542e-07,
#   17.236998152282702),
#  ('newspapers',
#   ('domestic eggs', 'yogurt'),
#   7.675802491449891e-07,
#   12.409453996231017),
#  ('onions',
#   ('soda', 'tropical fruit'),
#   1.0345646836302028e-06,
#   9.122412459764496),
#  ('citrus fruit',
#   ('domestic eggs', 'yogurt'),
#   9.94568960954402e-07,
#   9.084656887806858),
#  ('shopping bags',
#   ('domestic eggs', 'yogurt'),
#   8.896275284539718e-07,
#   10.143682901413557),
#  ('frankfurter',
#   ('domestic eggs', 'yogurt'),
#   7.008341405236856e-07,
#   12.782835797887527),
#  ('berries',
#   ('soda', 'tropical fruit'),
#   1.0345646836302028e-06,
#   8.478806672725895),
#  ('hamburger meat',
#   ('soda', 'tropical fruit'),
#   1.0345646836302028e-06,
#   8.45287760033224),
#  ('napkins',
#   ('soda', 'tropical fruit'),
#   1.0345646836302028e-06,
#   8.35072802208049),
#  ('coffee',
#   ('soda', 'tropical fruit'),
#   1.451972088233259e-06,
#   5.843744133844909),
#  ('chicken',
#   ('yogurt', 'root vegetables'),
#   1.0099357810970307e-06,
#   8.389214965527577),
#  ('ice cream',
#   ('domestic eggs', 'root vegetables'),
#   2.490646272441054e-07,
#   32.876853010279),
#  ('chocolate',
#   ('soda', 'tropical fruit'),
#   1.0345646836302028e-06,
#   7.83028604903298),
#  ('dessert',
#   ('soda', 'tropical fruit'),
#   1.0345646836302028e-06,
#   7.83028604903298),
#  ('cream cheese ',
#   ('soda', 'tropical fruit'),
#   1.0345646836302028e-06,
#   7.808166596917068),
#  ('white bread',
#   ('soda', 'tropical fruit'),
#   1.0371229201666134e-06,
#   7.699417758519894),
#  ('misc. beverages',
#   ('domestic eggs', 'root vegetables'),
#   2.490646272441054e-07,
#   31.623074717514125),
#  ('frozen vegetables',
#   ('soda', 'tropical fruit'),
#   1.1795903337918065e-06,
#   6.5968758360588104),
#  ('ice cream',
#   ('domestic eggs', 'photo/film'),
#   1.164610630454234e-07,
#   65.91629955947137),
#  ('ice cream',
#   ('white wine', 'yogurt'),
#   1.164610630454234e-07,
#   65.91629955947137),
#  ('ice cream',
#   ('white wine', 'root vegetables'),
#   1.164610630454234e-07,
#   65.91629955947137),
#  ('ice cream',
#   ('white wine', 'tropical fruit'),
#   1.164610630454234e-07,
#   65.91629955947137),
#  ('ice cream',
#   ('white wine', 'photo/film'),
#   1.164610630454234e-07,
#   65.91629955947137),
#  ('newspapers',
#   ('soda', 'tropical fruit'),
#   1.590255144255474e-06,
#   4.7492972084340925),
#  ('frozen meals',
#   ('domestic eggs', 'root vegetables'),
#   2.490646272441054e-07,
#   29.733249535192563),
#  ('misc. beverages',
#   ('domestic eggs', 'photo/film'),
#   1.164610630454234e-07,
#   63.40254237288135),
#  ('misc. beverages',
#   ('white wine', 'yogurt'),
#   1.164610630454234e-07,
#   63.40254237288135),
#  ('misc. beverages',
#   ('white wine', 'root vegetables'),
#   1.164610630454234e-07,
#   63.40254237288135),
#  ('misc. beverages',
#   ('white wine', 'tropical fruit'),
#   1.164610630454234e-07,
#   63.40254237288135),
#  ('misc. beverages',
#   ('white wine', 'photo/film'),
#   1.164610630454234e-07,
#   63.40254237288135),
#  ('margarine',
#   ('yogurt', 'root vegetables'),
#   1.0099357810970307e-06,
#   7.257889295902489),
#  ('ham',
#   ('domestic eggs', 'root vegetables'),
#   2.490646272441054e-07,
#   29.152522005208333),
#  ('citrus fruit',
#   ('soda', 'tropical fruit'),
#   2.0605251480041744e-06,
#   3.4768439940989206),
#  ('shopping bags',
#   ('soda', 'tropical fruit'),
#   1.8431098965496974e-06,
#   3.8821502462200033),
#  ('frankfurter',
#   ('soda', 'tropical fruit'),
#   1.451972088233259e-06,
#   4.892196416475473),
#  ('butter milk',
#   ('domestic eggs', 'root vegetables'),
#   2.490646272441054e-07,
#   28.376599366286438),
#  ('sugar',
#   ('domestic eggs', 'root vegetables'),
#   2.490646272441054e-07,
#   28.162436352201258),
#  ('curd',
#   ('yogurt', 'root vegetables'),
#   1.0099357810970307e-06,
#   6.941076667906746),
#  ('beef',
#   ('yogurt', 'root vegetables'),
#   1.0099357810970307e-06,
#   6.886422520915354),
#  ('chicken',
#   ('yogurt', 'photo/film'),
#   1.9373934734044705e-07,
#   35.882494004796165),
#  ('frozen meals',
#   ('domestic eggs', 'photo/film'),
#   1.164610630454234e-07,
#   59.61354581673307),
#  ('frozen meals',
#   ('white wine', 'yogurt'),
#   1.164610630454234e-07,
#   59.61354581673307),
#  ('frozen meals',
#   ('white wine', 'root vegetables'),
#   1.164610630454234e-07,
#   59.61354581673307),
#  ('frozen meals',
#   ('white wine', 'tropical fruit'),
#   1.164610630454234e-07,
#   59.61354581673307),
#  ('frozen meals',
#   ('white wine', 'photo/film'),
#   1.164610630454234e-07,
#   59.61354581673307),
#  ('fruit/vegetable juice',
#   ('yogurt', 'root vegetables'),
#   1.0099357810970307e-06,
#   6.872893203585463),
#  ('long life bakery product',
#   ('domestic eggs', 'root vegetables'),
#   2.490646272441054e-07,
#   27.847185199004972),
#  ('ham', ('domestic eggs', 'photo/film'), 1.164610630454234e-07, 58.44921875),
#  ('ham', ('white wine', 'yogurt'), 1.164610630454234e-07, 58.44921875),
#  ('ham',
#   ('white wine', 'root vegetables'),
#   1.164610630454234e-07,
#   58.44921875),
#  ('ham', ('white wine', 'tropical fruit'), 1.164610630454234e-07, 58.44921875),
#  ('ham', ('white wine', 'photo/film'), 1.164610630454234e-07, 58.44921875),
#  ('butter',
#   ('yogurt', 'root vegetables'),
#   1.0099357810970307e-06,
#   6.63814542813093),
#  ('butter milk',
#   ('domestic eggs', 'photo/film'),
#   1.164610630454234e-07,
#   56.893536121673),
#  ('butter milk',
#   ('white wine', 'yogurt'),
#   1.164610630454234e-07,
#   56.893536121673),
#  ('butter milk',
#   ('white wine', 'root vegetables'),
#   1.164610630454234e-07,
#   56.893536121673),
#  ('butter milk',
#   ('white wine', 'tropical fruit'),
#   1.164610630454234e-07,
#   56.893536121673),
#  ('butter milk',
#   ('white wine', 'photo/film'),
#   1.164610630454234e-07,
#   56.893536121673),
#  ('salty snack',
#   ('domestic eggs', 'root vegetables'),
#   2.490646272441054e-07,
#   26.558881257414),
#  ('sugar',
#   ('domestic eggs', 'photo/film'),
#   1.164610630454234e-07,
#   56.46415094339622),
#  ('sugar', ('white wine', 'yogurt'), 1.164610630454234e-07, 56.46415094339622),
#  ('sugar',
#   ('white wine', 'root vegetables'),
#   1.164610630454234e-07,
#   56.46415094339622),
#  ('sugar',
#   ('white wine', 'tropical fruit'),
#   1.164610630454234e-07,
#   56.46415094339622),
#  ('sugar',
#   ('white wine', 'photo/film'),
#   1.164610630454234e-07,
#   56.46415094339622),
#  ('long life bakery product',
#   ('domestic eggs', 'photo/film'),
#   1.164610630454234e-07,
#   55.832089552238806),
#  ('long life bakery product',
#   ('white wine', 'yogurt'),
#   1.164610630454234e-07,
#   55.832089552238806),
#  ('long life bakery product',
#   ('white wine', 'root vegetables'),
#   1.164610630454234e-07,
#   55.832089552238806),
#  ('long life bakery product',
#   ('white wine', 'tropical fruit'),
#   1.164610630454234e-07,
#   55.832089552238806),
#  ('long life bakery product',
#   ('white wine', 'photo/film'),
#   1.164610630454234e-07,
#   55.832089552238806),
#  ('pork',
#   ('yogurt', 'root vegetables'),
#   1.0099357810970307e-06,
#   6.303248001126126),
#  ('oil', ('soda', 'yogurt'), 5.494530104316083e-07, 11.540197360960775),
#  ('specialty chocolate',
#   ('soda', 'yogurt'),
#   5.832093097794776e-07,
#   10.767631847256288),
#  ('brown bread',
#   ('yogurt', 'root vegetables'),
#   1.0099357810970307e-06,
#   6.213681422069271),
#  ('salty snack',
#   ('domestic eggs', 'photo/film'),
#   1.164610630454234e-07,
#   53.2491103202847),
#  ('salty snack',
#   ('white wine', 'yogurt'),
#   1.164610630454234e-07,
#   53.2491103202847),
#  ('salty snack',
#   ('white wine', 'root vegetables'),
#   1.164610630454234e-07,
#   53.2491103202847),
#  ('salty snack',
#   ('white wine', 'tropical fruit'),
#   1.164610630454234e-07,
#   53.2491103202847),
#  ('salty snack',
#   ('white wine', 'photo/film'),
#   1.164610630454234e-07,
#   53.2491103202847),
#  ('onions',
#   ('domestic eggs', 'root vegetables'),
#   2.490646272441054e-07,
#   24.63051364136414),
#  ('margarine',
#   ('yogurt', 'photo/film'),
#   1.9373934734044705e-07,
#   31.04356846473029),
#  ('beverages', ('soda', 'yogurt'), 5.698031219290753e-07, 10.37687101408973),
#  ('meat', ('soda', 'yogurt'), 5.680828435315948e-07, 10.212158775770845),
#  ('curd',
#   ('yogurt', 'photo/film'),
#   1.9373934734044705e-07,
#   29.688492063492067),
#  ('onions',
#   ('domestic eggs', 'photo/film'),
#   1.164610630454234e-07,
#   49.382838283828384),
#  ('onions',
#   ('white wine', 'yogurt'),
#   1.164610630454234e-07,
#   49.382838283828384),
#  ('onions',
#   ('white wine', 'root vegetables'),
#   1.164610630454234e-07,
#   49.382838283828384),
#  ('onions',
#   ('white wine', 'tropical fruit'),
#   1.164610630454234e-07,
#   49.382838283828384),
#  ('onions',
#   ('white wine', 'photo/film'),
#   1.164610630454234e-07,
#   49.382838283828384),
#  ('beef', ('yogurt', 'photo/film'), 1.9373934734044705e-07, 29.45472440944882),
#  ('berries',
#   ('domestic eggs', 'root vegetables'),
#   2.490646272441054e-07,
#   22.892778016359916),
#  ('fruit/vegetable juice',
#   ('yogurt', 'photo/film'),
#   1.9373934734044705e-07,
#   29.396856581532415),
#  ('hamburger meat',
#   ('domestic eggs', 'root vegetables'),
#   2.490646272441054e-07,
#   22.822769520897044),
#  ('napkins',
#   ('domestic eggs', 'root vegetables'),
#   2.490646272441054e-07,
#   22.54696565961732),
#  ('rolls/buns',
#   ('root vegetables', 'photo/film'),
#   6.164433779014225e-07,
#   9.09052247873633),
#  ('rolls/buns',
#   ('tropical fruit', 'photo/film'),
#   6.164433779014225e-07,
#   9.09052247873633),
#  ('rolls/buns',
#   ('soda', 'domestic eggs', 'white wine'),
#   6.164433779014225e-07,
#   9.09052247873633),
#  ('rolls/buns',
#   ('soda', 'domestic eggs', 'yogurt'),
#   6.164433779014225e-07,
#   9.09052247873633),
#  ('rolls/buns',
#   ('soda', 'domestic eggs', 'root vegetables'),
#   6.164433779014225e-07,
#   9.09052247873633),
#  ('rolls/buns',
#   ('soda', 'domestic eggs', 'tropical fruit'),
#   6.164433779014225e-07,
#   9.09052247873633),
#  ('rolls/buns',
#   ('soda', 'domestic eggs', 'photo/film'),
#   6.164433779014225e-07,
#   9.09052247873633),
#  ...]
